# %%
# import import_ipynb
from classes import *
import classes
import tensorflow as tf
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, recall_score, accuracy_score, precision_score

from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout, UpSampling2D, Input, Convolution2D, Reshape

known_volume_path = 'C:/Users/GJ/Desktop/연구실/2022SPCUP/spcup_2022_training_part1'
unknown_volume_path = './spcup_2022_unseen'




rs = 10
known_path, known_labels = file_path_list(known_volume_path)
unknown_path, unknown_labels = file_path_list(unknown_volume_path)
##train set
# print('raw train_set_num :',len(labels))
X_train_path, X_test_path, y_train_raw, y_test_raw = train_test_split(np.array(known_path),
                                                                      known_labels, test_size=0.2,
                                                                      stratify = known_labels, random_state=rs)


n_mels = 64

# train = classes.data(X_train_path, y_train_raw, n_mels=n_mels, known = True)
# # X_train,y_train = train.extract_mel(sampling_rate,n_mels)
#
# test = classes.data(X_test_path, y_test_raw, n_mels=n_mels, known = True)
# # X_test,y_test = test.extract_mel(sampling_rate,n_mels)
#
# unseen = data(unknown_path, unknown_labels, n_mels=n_mels, known = False)

n = -1
train = classes.data(X_train_path[:n],y_train_raw[:n],n_mels=n_mels, known = True)

test = classes.data(X_test_path[:n],y_test_raw[:n], n_mels=n_mels, known = True)

unseen =data(unknown_path[:n],unknown_labels[:n], n_mels=n_mels, known = False)


train_t = train.X_split.transpose((0, 2, 1))
test_t = test.X_split.transpose((0, 2, 1))
unseen_t = unseen.X_split.transpose((0, 2, 1))

# %%
X_train = train.X_split.reshape((train.X_split.shape[0],1,train.X_split.shape[1],train.X_split.shape[2]))
X_test = test.X_split.reshape(( test.X_split.shape[0],1,test.X_split.shape[1],test.X_split.shape[2]))
X_unseen = unseen.X_split.reshape((unseen.X_split.shape[0],1, unseen.X_split.shape[1],unseen.X_split.shape[2]))
print(X_train.shape)
print(train.X_split.shape
# Out:
# (68, 1, 64, 32)
# (68, 64, 32)

# %%
import pandas as pd
import numpy as np



epochs = 100
batch_size = 64
window_length = 16
feats = n_mels


model = keras.Sequential()
model.add(keras.layers.LSTM(64, kernel_initializer='he_uniform', input_shape=(window_length, feats), return_sequences=True, name='encoder_1'))
model.add(keras.layers.LSTM(32, kernel_initializer='he_uniform', return_sequences=True, name='encoder_2'))
model.add(keras.layers.LSTM(16, kernel_initializer='he_uniform', return_sequences=True, name='encoder_3'))
# model.add(keras.layers.RepeatVector(window_length, name='encoder_decoder_bridge'))
model.add(keras.layers.LSTM(16, kernel_initializer='he_uniform', return_sequences=True, name='decoder_1'))
model.add(keras.layers.LSTM(32, kernel_initializer='he_uniform', return_sequences=True, name='decoder_2'))
model.add(keras.layers.LSTM(64, kernel_initializer='he_uniform', return_sequences=True, name='decoder_3'))
model.add(keras.layers.TimeDistributed(keras.layers.Dense(feats)))

model.compile(loss="mse",optimizer='adam')

model.build()
print(model.summary())


early_stop = tf.keras.callbacks.EarlyStopping( monitor='val_loss', min_delta=0.1,
                                              patience=100, verbose=1, mode='min', restore_best_weights=True)

history = model.fit(x=train_t, y=train_t, validation_split = 0.2, epochs=1000, batch_size=batch_size, shuffle=True, callbacks=[early_stop]).history



plt.plot(history['loss'], linewidth=2, label='Train')
plt.plot(history['val_loss'], linewidth=2, label='val')
plt.legend(loc='upper right')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch') #plt.ylim(ymin=0.70,ymax=1) plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_1 (LSTM)             (None, 16, 64)            33024
# _________________________________________________________________
# encoder_2 (LSTM)             (None, 16, 32)            12416
# _________________________________________________________________
# encoder_3 (LSTM)             (None, 16, 16)            3136
# _________________________________________________________________
# decoder_1 (LSTM)             (None, 16, 16)            2112
# _________________________________________________________________
# decoder_2 (LSTM)             (None, 16, 32)            6272
# _________________________________________________________________
# decoder_3 (LSTM)             (None, 16, 64)            24832
# _________________________________________________________________
# time_distributed (TimeDistri (None, 16, 64)            4160
# =================================================================
# Total params: 85,952
# Trainable params: 85,952
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/1000
# WARNING:tensorflow:Model was constructed with shape (None, 16, 64) for input KerasTensor(type_spec=TensorSpec(shape=(None, 16, 64), dtype=tf.float32, name='encoder_1_input'), name='encoder_1_input', description="created by layer 'encoder_1_input'"), but it was called on an input with incompatible shape (None, 32, 64).
# WARNING:tensorflow:Model was constructed with shape (None, 16, 64) for input KerasTensor(type_spec=TensorSpec(shape=(None, 16, 64), dtype=tf.float32, name='encoder_1_input'), name='encoder_1_input', description="created by layer 'encoder_1_input'"), but it was called on an input with incompatible shape (None, 32, 64).
# 645/646 [============================>.] - ETA: 0s - loss: 891.0016WARNING:tensorflow:Model was constructed with shape (None, 16, 64) for input KerasTensor(type_spec=TensorSpec(shape=(None, 16, 64), dtype=tf.float32, name='encoder_1_input'), name='encoder_1_input', description="created by layer 'encoder_1_input'"), but it was called on an input with incompatible shape (None, 32, 64).
# 646/646 [==============================] - 34s 40ms/step - loss: 890.8906 - val_loss: 787.3961
# Epoch 2/1000
# 646/646 [==============================] - 15s 22ms/step - loss: 772.7725 - val_loss: 729.8043
# Epoch 3/1000
# 646/646 [==============================] - 20s 31ms/step - loss: 710.9935 - val_loss: 694.0875
# Epoch 4/1000
# 646/646 [==============================] - 20s 31ms/step - loss: 696.2737 - val_loss: 655.1129
# Epoch 5/1000
# 646/646 [==============================] - 21s 32ms/step - loss: 636.2685 - val_loss: 619.2134
# Epoch 6/1000
# 646/646 [==============================] - 14s 22ms/step - loss: 612.9840 - val_loss: 587.4570
# Epoch 7/1000
# 646/646 [==============================] - 15s 23ms/step - loss: 591.8279 - val_loss: 556.1856
# Epoch 8/1000
# 646/646 [==============================] - 21s 33ms/step - loss: 551.2315 - val_loss: 522.0133
# Epoch 9/1000
# 646/646 [==============================] - 16s 24ms/step - loss: 512.4672 - val_loss: 488.0834
# Epoch 10/1000
# 646/646 [==============================] - 16s 25ms/step - loss: 479.7926 - val_loss: 456.6410
# Epoch 11/1000
# 646/646 [==============================] - 14s 21ms/step - loss: 454.4302 - val_loss: 428.2845
# Epoch 12/1000
# 646/646 [==============================] - 19s 29ms/step - loss: 418.2796 - val_loss: 401.3773
# Epoch 13/1000
# 646/646 [==============================] - 16s 24ms/step - loss: 402.2896 - val_loss: 376.6956
# Epoch 14/1000
# 646/646 [==============================] - 14s 21ms/step - loss: 371.2182 - val_loss: 354.0266
# Epoch 15/1000
# 646/646 [==============================] - 19s 30ms/step - loss: 348.7238 - val_loss: 333.5136
# Epoch 16/1000
# 646/646 [==============================] - 18s 28ms/step - loss: 329.9789 - val_loss: 314.9941
# Epoch 17/1000
# 646/646 [==============================] - 14s 21ms/step - loss: 306.2248 - val_loss: 297.0236
# Epoch 18/1000
# 646/646 [==============================] - 14s 21ms/step - loss: 297.9798 - val_loss: 280.4750
# Epoch 19/1000
# 646/646 [==============================] - 13s 21ms/step - loss: 281.2212 - val_loss: 265.2120
# Epoch 20/1000
# 646/646 [==============================] - 14s 21ms/step - loss: 260.1559 - val_loss: 251.0563
# Epoch 21/1000
# 646/646 [==============================] - 13s 19ms/step - loss: 244.8130 - val_loss: 237.4376
# Epoch 22/1000
# 646/646 [==============================] - 14s 22ms/step - loss: 239.1599 - val_loss: 225.0358
# Epoch 23/1000
# 646/646 [==============================] - 15s 23ms/step - loss: 221.3726 - val_loss: 212.9983
# Epoch 24/1000
# 646/646 [==============================] - 18s 28ms/step - loss: 209.7795 - val_loss: 202.5261
# Epoch 25/1000
# 646/646 [==============================] - 15s 23ms/step - loss: 199.6050 - val_loss: 191.6113
# Epoch 26/1000
# 646/646 [==============================] - 15s 23ms/step - loss: 186.2954 - val_loss: 182.1019
# Epoch 27/1000
# 646/646 [==============================] - 18s 28ms/step - loss: 182.1107 - val_loss: 173.1177
# Epoch 28/1000
# 646/646 [==============================] - 18s 27ms/step - loss: 169.4090 - val_loss: 164.9564
# Epoch 29/1000
# 646/646 [==============================] - 18s 27ms/step - loss: 161.8606 - val_loss: 157.3369
# Epoch 30/1000
# 646/646 [==============================] - 14s 22ms/step - loss: 156.0735 - val_loss: 149.7231
# Epoch 31/1000
# 646/646 [==============================] - 14s 21ms/step - loss: 153.5479 - val_loss: 143.2693
# Epoch 32/1000
# 646/646 [==============================] - 14s 22ms/step - loss: 135.6029 - val_loss: 136.6626
# Epoch 33/1000
# 646/646 [==============================] - 14s 22ms/step - loss: 129.6822 - val_loss: 130.3182
# Epoch 34/1000
# 646/646 [==============================] - 16s 25ms/step - loss: 130.0549 - val_loss: 125.2327
# Epoch 35/1000
# 646/646 [==============================] - 17s 26ms/step - loss: 123.1190 - val_loss: 119.4909
# Epoch 36/1000
# 646/646 [==============================] - 16s 24ms/step - loss: 117.3532 - val_loss: 114.7903
# Epoch 37/1000
# 646/646 [==============================] - 14s 21ms/step - loss: 119.7929 - val_loss: 110.4952
# Epoch 38/1000
# 646/646 [==============================] - 16s 26ms/step - loss: 112.2379 - val_loss: 106.3755
# Epoch 39/1000
# 646/646 [==============================] - 15s 24ms/step - loss: 104.0981 - val_loss: 101.6117
# Epoch 40/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 99.7509 - val_loss: 98.1265
# Epoch 41/1000
# 646/646 [==============================] - 13s 21ms/step - loss: 99.4969 - val_loss: 94.1688
# Epoch 42/1000
# 646/646 [==============================] - 18s 29ms/step - loss: 92.3113 - val_loss: 91.1329
# Epoch 43/1000
# 646/646 [==============================] - 17s 26ms/step - loss: 87.0496 - val_loss: 87.5118
# Epoch 44/1000
# 646/646 [==============================] - 17s 26ms/step - loss: 86.6997 - val_loss: 84.6196
# Epoch 45/1000
# 646/646 [==============================] - 16s 25ms/step - loss: 84.5781 - val_loss: 82.0093
# Epoch 46/1000
# 646/646 [==============================] - 14s 22ms/step - loss: 79.5192 - val_loss: 78.9198
# Epoch 47/1000
# 646/646 [==============================] - 18s 28ms/step - loss: 75.9039 - val_loss: 76.3877
# Epoch 48/1000
# 646/646 [==============================] - 17s 27ms/step - loss: 75.0395 - val_loss: 74.0555
# Epoch 49/1000
# 646/646 [==============================] - 18s 27ms/step - loss: 74.9112 - val_loss: 71.9918
# Epoch 50/1000
# 646/646 [==============================] - 14s 22ms/step - loss: 69.2274 - val_loss: 69.7172
# Epoch 51/1000
# 646/646 [==============================] - 19s 29ms/step - loss: 67.8766 - val_loss: 68.1063
# Epoch 52/1000
# 646/646 [==============================] - 14s 22ms/step - loss: 66.5230 - val_loss: 65.5209
# Epoch 53/1000
# 646/646 [==============================] - 16s 25ms/step - loss: 68.2204 - val_loss: 63.8279
# Epoch 54/1000
# 646/646 [==============================] - 19s 29ms/step - loss: 60.1394 - val_loss: 62.3844
# Epoch 55/1000
# 646/646 [==============================] - 20s 32ms/step - loss: 61.8677 - val_loss: 60.5581
# Epoch 56/1000
# 646/646 [==============================] - 20s 31ms/step - loss: 59.6775 - val_loss: 58.7268
# Epoch 57/1000
# 646/646 [==============================] - 14s 22ms/step - loss: 58.2380 - val_loss: 57.6524
# Epoch 58/1000
# 646/646 [==============================] - 21s 32ms/step - loss: 56.5786 - val_loss: 56.2036
# Epoch 59/1000
# 646/646 [==============================] - 21s 32ms/step - loss: 53.9945 - val_loss: 54.3956
# Epoch 60/1000
# 646/646 [==============================] - 21s 33ms/step - loss: 54.5923 - val_loss: 54.3881
# Epoch 61/1000
# 646/646 [==============================] - 20s 31ms/step - loss: 55.6079 - val_loss: 51.9652
# Epoch 62/1000
# 646/646 [==============================] - 22s 33ms/step - loss: 54.2815 - val_loss: 50.9141
# Epoch 63/1000
# 646/646 [==============================] - 22s 34ms/step - loss: 52.4945 - val_loss: 50.1803
# Epoch 64/1000
# 646/646 [==============================] - 20s 30ms/step - loss: 48.4171 - val_loss: 49.5535
# Epoch 65/1000
# 646/646 [==============================] - 19s 30ms/step - loss: 48.7158 - val_loss: 48.0751
# Epoch 66/1000
# 646/646 [==============================] - 14s 21ms/step - loss: 47.3178 - val_loss: 47.2890
# Epoch 67/1000
# 646/646 [==============================] - 19s 29ms/step - loss: 48.0288 - val_loss: 45.7569
# Epoch 68/1000
# 646/646 [==============================] - 16s 25ms/step - loss: 42.7104 - val_loss: 45.1077
# Epoch 69/1000
# 646/646 [==============================] - 19s 30ms/step - loss: 44.7508 - val_loss: 44.2059
# Epoch 70/1000
# 646/646 [==============================] - 17s 26ms/step - loss: 44.3763 - val_loss: 43.3658
# Epoch 71/1000
# 646/646 [==============================] - 15s 23ms/step - loss: 42.9790 - val_loss: 42.9397
# Epoch 72/1000
# 646/646 [==============================] - 12s 18ms/step - loss: 41.8140 - val_loss: 42.6930
# Epoch 73/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 43.2677 - val_loss: 41.1884
# Epoch 74/1000
# 646/646 [==============================] - 23s 36ms/step - loss: 40.0304 - val_loss: 40.7746
# Epoch 75/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 39.0617 - val_loss: 39.7656
# Epoch 76/1000
# 646/646 [==============================] - 23s 35ms/step - loss: 42.0547 - val_loss: 39.5714
# Epoch 77/1000
# 646/646 [==============================] - 22s 33ms/step - loss: 37.8780 - val_loss: 38.8411
# Epoch 78/1000
# 646/646 [==============================] - 23s 35ms/step - loss: 37.2141 - val_loss: 38.5873
# Epoch 79/1000
# 646/646 [==============================] - 15s 23ms/step - loss: 37.8065 - val_loss: 37.8822
# Epoch 80/1000
# 646/646 [==============================] - 22s 33ms/step - loss: 35.0163 - val_loss: 36.5947
# Epoch 81/1000
# 646/646 [==============================] - 21s 33ms/step - loss: 37.1500 - val_loss: 36.1483
# Epoch 82/1000
# 646/646 [==============================] - 24s 36ms/step - loss: 33.7917 - val_loss: 35.4562
# Epoch 83/1000
# 646/646 [==============================] - 22s 35ms/step - loss: 35.5634 - val_loss: 35.4633
# Epoch 84/1000
# 646/646 [==============================] - 22s 34ms/step - loss: 35.8237 - val_loss: 34.8021
# Epoch 85/1000
# 646/646 [==============================] - 18s 28ms/step - loss: 33.0666 - val_loss: 34.9037
# Epoch 86/1000
# 646/646 [==============================] - 21s 32ms/step - loss: 33.8251 - val_loss: 33.4818
# Epoch 87/1000
# 646/646 [==============================] - 22s 35ms/step - loss: 32.3107 - val_loss: 33.4928
# Epoch 88/1000
# 646/646 [==============================] - 21s 32ms/step - loss: 35.4066 - val_loss: 33.2561
# Epoch 89/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 31.7644 - val_loss: 32.5950
# Epoch 90/1000
# 646/646 [==============================] - 23s 36ms/step - loss: 32.5126 - val_loss: 31.5457
# Epoch 91/1000
# 646/646 [==============================] - 21s 32ms/step - loss: 32.6868 - val_loss: 31.3623
# Epoch 92/1000
# 646/646 [==============================] - 20s 31ms/step - loss: 30.8433 - val_loss: 30.7796
# Epoch 93/1000
# 646/646 [==============================] - 17s 26ms/step - loss: 31.0881 - val_loss: 31.2270
# Epoch 94/1000
# 646/646 [==============================] - 16s 24ms/step - loss: 30.2302 - val_loss: 31.0597
# Epoch 95/1000
# 646/646 [==============================] - 18s 27ms/step - loss: 30.7842 - val_loss: 32.0123
# Epoch 96/1000
# 646/646 [==============================] - 14s 22ms/step - loss: 30.9723 - val_loss: 29.6525
# Epoch 97/1000
# 646/646 [==============================] - 14s 22ms/step - loss: 29.5843 - val_loss: 29.4895
# Epoch 98/1000
# 646/646 [==============================] - 15s 23ms/step - loss: 30.7746 - val_loss: 29.8155
# Epoch 99/1000
# 646/646 [==============================] - 22s 34ms/step - loss: 29.0470 - val_loss: 28.8995
# Epoch 100/1000
# 646/646 [==============================] - 23s 35ms/step - loss: 27.5984 - val_loss: 28.6171
# Epoch 101/1000
# 646/646 [==============================] - 22s 33ms/step - loss: 27.0352 - val_loss: 28.3417
# Epoch 102/1000
# 646/646 [==============================] - 22s 35ms/step - loss: 31.3342 - val_loss: 28.7978
# Epoch 103/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 26.6181 - val_loss: 27.5629
# Epoch 104/1000
# 646/646 [==============================] - 23s 35ms/step - loss: 26.9049 - val_loss: 27.1967
# Epoch 105/1000
# 646/646 [==============================] - 16s 25ms/step - loss: 26.3611 - val_loss: 27.7078
# Epoch 106/1000
# 646/646 [==============================] - 16s 24ms/step - loss: 27.8395 - val_loss: 26.7691
# Epoch 107/1000
# 646/646 [==============================] - 21s 32ms/step - loss: 25.3527 - val_loss: 27.5381
# Epoch 108/1000
# 646/646 [==============================] - 21s 33ms/step - loss: 26.3016 - val_loss: 26.8684
# Epoch 109/1000
# 646/646 [==============================] - 21s 32ms/step - loss: 24.4551 - val_loss: 26.3395
# Epoch 110/1000
# 646/646 [==============================] - 23s 36ms/step - loss: 25.8875 - val_loss: 26.6490
# Epoch 111/1000
# 646/646 [==============================] - 23s 35ms/step - loss: 25.2447 - val_loss: 26.3968
# Epoch 112/1000
# 646/646 [==============================] - 21s 33ms/step - loss: 25.5921 - val_loss: 25.2811
# Epoch 113/1000
# 646/646 [==============================] - 23s 35ms/step - loss: 24.6886 - val_loss: 25.2324
# Epoch 114/1000
# 646/646 [==============================] - 23s 36ms/step - loss: 24.2212 - val_loss: 25.4434
# Epoch 115/1000
# 646/646 [==============================] - 23s 36ms/step - loss: 23.1032 - val_loss: 25.3173
# Epoch 116/1000
# 646/646 [==============================] - 22s 35ms/step - loss: 25.4481 - val_loss: 24.5364
# Epoch 117/1000
# 646/646 [==============================] - 22s 35ms/step - loss: 24.8570 - val_loss: 24.4692
# Epoch 118/1000
# 646/646 [==============================] - 17s 26ms/step - loss: 23.2802 - val_loss: 24.4256
# Epoch 119/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 23.1508 - val_loss: 25.0373
# Epoch 120/1000
# 646/646 [==============================] - 15s 24ms/step - loss: 22.8818 - val_loss: 25.2440
# Epoch 121/1000
# 646/646 [==============================] - 22s 34ms/step - loss: 24.3836 - val_loss: 23.5241
# Epoch 122/1000
# 646/646 [==============================] - 23s 36ms/step - loss: 23.0392 - val_loss: 24.0160
# Epoch 123/1000
# 646/646 [==============================] - 23s 36ms/step - loss: 24.5601 - val_loss: 23.5023
# Epoch 124/1000
# 646/646 [==============================] - 23s 36ms/step - loss: 23.3149 - val_loss: 23.5491
# Epoch 125/1000
# 646/646 [==============================] - 23s 36ms/step - loss: 23.6871 - val_loss: 24.5014
# Epoch 126/1000
# 646/646 [==============================] - 17s 27ms/step - loss: 23.1073 - val_loss: 23.1337
# Epoch 127/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 21.9416 - val_loss: 22.5880
# Epoch 128/1000
# 646/646 [==============================] - 23s 36ms/step - loss: 22.1334 - val_loss: 24.0975
# Epoch 129/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 22.2925 - val_loss: 22.0857
# Epoch 130/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 22.2610 - val_loss: 22.7371
# Epoch 131/1000
# 646/646 [==============================] - 18s 28ms/step - loss: 21.1241 - val_loss: 22.3035
# Epoch 132/1000
# 646/646 [==============================] - 22s 33ms/step - loss: 23.7374 - val_loss: 22.0787
# Epoch 133/1000
# 646/646 [==============================] - 23s 35ms/step - loss: 20.6660 - val_loss: 24.4735
# Epoch 134/1000
# 646/646 [==============================] - 23s 36ms/step - loss: 21.6882 - val_loss: 21.7705
# Epoch 135/1000
# 646/646 [==============================] - 23s 35ms/step - loss: 20.8422 - val_loss: 21.7063
# Epoch 136/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 20.5299 - val_loss: 22.0968
# Epoch 137/1000
# 646/646 [==============================] - 22s 35ms/step - loss: 20.3985 - val_loss: 22.1693
# Epoch 138/1000
# 646/646 [==============================] - 24s 36ms/step - loss: 21.5324 - val_loss: 21.0508
# Epoch 139/1000
# 646/646 [==============================] - 22s 34ms/step - loss: 21.2325 - val_loss: 21.0371
# Epoch 140/1000
# 646/646 [==============================] - 24s 36ms/step - loss: 20.7335 - val_loss: 21.1884
# Epoch 141/1000
# 646/646 [==============================] - 23s 36ms/step - loss: 19.1216 - val_loss: 21.0695
# Epoch 142/1000
# 646/646 [==============================] - 23s 36ms/step - loss: 21.4475 - val_loss: 21.6355
# Epoch 143/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 20.8786 - val_loss: 21.4678
# Epoch 144/1000
# 646/646 [==============================] - 22s 35ms/step - loss: 20.2550 - val_loss: 20.0265
# Epoch 145/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 22.0486 - val_loss: 19.9009
# Epoch 146/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 20.2167 - val_loss: 20.6191
# Epoch 147/1000
# 646/646 [==============================] - 22s 35ms/step - loss: 19.7229 - val_loss: 20.1277
# Epoch 148/1000
# 646/646 [==============================] - 22s 35ms/step - loss: 21.2898 - val_loss: 20.0002
# Epoch 149/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 19.2920 - val_loss: 19.6242
# Epoch 150/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 19.6545 - val_loss: 20.0005
# Epoch 151/1000
# 646/646 [==============================] - 24s 36ms/step - loss: 19.2818 - val_loss: 19.3427
# Epoch 152/1000
# 646/646 [==============================] - 24s 36ms/step - loss: 18.5732 - val_loss: 19.9054
# Epoch 153/1000
# 646/646 [==============================] - 24s 36ms/step - loss: 19.7643 - val_loss: 18.9840
# Epoch 154/1000
# 646/646 [==============================] - 24s 36ms/step - loss: 18.7147 - val_loss: 19.7545: 0s - loss: 18.71
# Epoch 155/1000
# 646/646 [==============================] - 23s 36ms/step - loss: 18.6563 - val_loss: 18.7379
# Epoch 156/1000
# 646/646 [==============================] - 23s 36ms/step - loss: 18.8652 - val_loss: 21.4645
# Epoch 157/1000
# 646/646 [==============================] - 24s 36ms/step - loss: 18.7283 - val_loss: 20.1151
# Epoch 158/1000
# 646/646 [==============================] - 23s 36ms/step - loss: 17.8773 - val_loss: 18.8636
# Epoch 159/1000
# 646/646 [==============================] - 24s 36ms/step - loss: 20.4402 - val_loss: 19.0918
# Epoch 160/1000
# 646/646 [==============================] - 23s 36ms/step - loss: 17.5192 - val_loss: 19.2351
# Epoch 161/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 18.8121 - val_loss: 18.3941
# Epoch 162/1000
# 646/646 [==============================] - 22s 33ms/step - loss: 19.2181 - val_loss: 19.0687
# Epoch 163/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 18.8984 - val_loss: 18.1272
# Epoch 164/1000
# 646/646 [==============================] - 23s 36ms/step - loss: 18.1390 - val_loss: 18.5068
# Epoch 165/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 18.2085 - val_loss: 18.2209
# Epoch 166/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 17.6620 - val_loss: 18.3299
# Epoch 167/1000
# 646/646 [==============================] - 24s 36ms/step - loss: 17.8332 - val_loss: 17.7939
# Epoch 168/1000
# 646/646 [==============================] - 13s 21ms/step - loss: 17.8417 - val_loss: 19.1116
# Epoch 169/1000
# 646/646 [==============================] - 19s 30ms/step - loss: 17.7998 - val_loss: 17.6367
# Epoch 170/1000
# 646/646 [==============================] - 23s 36ms/step - loss: 17.9890 - val_loss: 18.1336
# Epoch 171/1000
# 646/646 [==============================] - 24s 36ms/step - loss: 16.4335 - val_loss: 17.9640
# Epoch 172/1000
# 646/646 [==============================] - 23s 36ms/step - loss: 18.1158 - val_loss: 17.5097
# Epoch 173/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 17.3481 - val_loss: 17.5967
# Epoch 174/1000
# 646/646 [==============================] - 23s 36ms/step - loss: 17.5766 - val_loss: 17.8645
# Epoch 175/1000
# 646/646 [==============================] - 23s 36ms/step - loss: 17.4073 - val_loss: 18.0480
# Epoch 176/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 16.9691 - val_loss: 18.7426
# Epoch 177/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 17.4390 - val_loss: 17.6953
# Epoch 178/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 16.7713 - val_loss: 17.1539
# Epoch 179/1000
# 646/646 [==============================] - 23s 35ms/step - loss: 17.2343 - val_loss: 17.6361
# Epoch 180/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 16.5874 - val_loss: 16.7646
# Epoch 181/1000
# 646/646 [==============================] - 13s 21ms/step - loss: 15.6595 - val_loss: 16.6970
# Epoch 182/1000
# 646/646 [==============================] - 22s 34ms/step - loss: 18.6068 - val_loss: 17.0324
# Epoch 183/1000
# 646/646 [==============================] - 17s 27ms/step - loss: 16.6598 - val_loss: 17.2123
# Epoch 184/1000
# 646/646 [==============================] - 23s 35ms/step - loss: 17.5497 - val_loss: 16.7784
# Epoch 185/1000
# 646/646 [==============================] - 22s 35ms/step - loss: 16.5118 - val_loss: 17.0173
# Epoch 186/1000
# 646/646 [==============================] - 22s 33ms/step - loss: 16.4243 - val_loss: 16.6876
# Epoch 187/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 17.2054 - val_loss: 16.8531
# Epoch 188/1000
# 646/646 [==============================] - 23s 36ms/step - loss: 15.7013 - val_loss: 17.3997
# Epoch 189/1000
# 646/646 [==============================] - 21s 33ms/step - loss: 16.8250 - val_loss: 15.8064
# Epoch 190/1000
# 646/646 [==============================] - 20s 31ms/step - loss: 14.9496 - val_loss: 17.1158
# Epoch 191/1000
# 646/646 [==============================] - 23s 35ms/step - loss: 16.7982 - val_loss: 16.8742
# Epoch 192/1000
# 646/646 [==============================] - 23s 36ms/step - loss: 16.3649 - val_loss: 17.1658
# Epoch 193/1000
# 646/646 [==============================] - 24s 36ms/step - loss: 14.5101 - val_loss: 15.9519
# Epoch 194/1000
# 646/646 [==============================] - 21s 33ms/step - loss: 14.2955 - val_loss: 16.9905
# Epoch 195/1000
# 646/646 [==============================] - 23s 36ms/step - loss: 14.9328 - val_loss: 15.8624
# Epoch 196/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 15.5783 - val_loss: 16.0600
# Epoch 197/1000
# 646/646 [==============================] - 23s 36ms/step - loss: 16.7566 - val_loss: 16.0502
# Epoch 198/1000
# 646/646 [==============================] - 23s 36ms/step - loss: 16.0436 - val_loss: 16.7515
# Epoch 199/1000
# 646/646 [==============================] - 24s 36ms/step - loss: 15.2544 - val_loss: 15.7408
# Epoch 200/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 14.9101 - val_loss: 15.7941
# Epoch 201/1000
# 646/646 [==============================] - 24s 36ms/step - loss: 15.4961 - val_loss: 16.6951
# Epoch 202/1000
# 646/646 [==============================] - 24s 36ms/step - loss: 16.2970 - val_loss: 15.8467
# Epoch 203/1000
# 646/646 [==============================] - 23s 35ms/step - loss: 15.5263 - val_loss: 15.3378
# Epoch 204/1000
# 646/646 [==============================] - 22s 34ms/step - loss: 15.3773 - val_loss: 15.2166
# Epoch 205/1000
# 646/646 [==============================] - 23s 36ms/step - loss: 15.0484 - val_loss: 15.9859
# Epoch 206/1000
# 646/646 [==============================] - 23s 36ms/step - loss: 16.2916 - val_loss: 15.3811
# Epoch 207/1000
# 646/646 [==============================] - 23s 36ms/step - loss: 14.2404 - val_loss: 15.7748
# Epoch 208/1000
# 646/646 [==============================] - 23s 36ms/step - loss: 15.6459 - val_loss: 16.6620
# Epoch 209/1000
# 646/646 [==============================] - 23s 36ms/step - loss: 14.7083 - val_loss: 15.4651
# Epoch 210/1000
# 646/646 [==============================] - 23s 36ms/step - loss: 15.9291 - val_loss: 15.0656
# Epoch 211/1000
# 646/646 [==============================] - 23s 35ms/step - loss: 15.3066 - val_loss: 15.4526
# Epoch 212/1000
# 646/646 [==============================] - 14s 22ms/step - loss: 14.6354 - val_loss: 15.0126
# Epoch 213/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 14.3283 - val_loss: 15.6422
# Epoch 214/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 14.3775 - val_loss: 15.5643
# Epoch 215/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 15.1473 - val_loss: 15.2677
# Epoch 216/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 15.1375 - val_loss: 15.4077
# Epoch 217/1000
# 646/646 [==============================] - 17s 27ms/step - loss: 14.7664 - val_loss: 14.9669
# Epoch 218/1000
# 646/646 [==============================] - 20s 30ms/step - loss: 14.7000 - val_loss: 15.0175
# Epoch 219/1000
# 646/646 [==============================] - 20s 30ms/step - loss: 17.1815 - val_loss: 16.2809
# Epoch 220/1000
# 646/646 [==============================] - 20s 31ms/step - loss: 14.3865 - val_loss: 16.3929
# Epoch 221/1000
# 646/646 [==============================] - 19s 30ms/step - loss: 14.7106 - val_loss: 14.8192
# Epoch 222/1000
# 646/646 [==============================] - 19s 30ms/step - loss: 14.0155 - val_loss: 15.5269
# Epoch 223/1000
# 646/646 [==============================] - 15s 23ms/step - loss: 16.5913 - val_loss: 15.7104
# Epoch 224/1000
# 646/646 [==============================] - 14s 22ms/step - loss: 13.7207 - val_loss: 14.5081
# Epoch 225/1000
# 646/646 [==============================] - 18s 28ms/step - loss: 13.6086 - val_loss: 16.8379
# Epoch 226/1000
# 646/646 [==============================] - 20s 30ms/step - loss: 14.7936 - val_loss: 14.7642
# Epoch 227/1000
# 646/646 [==============================] - 20s 31ms/step - loss: 13.2730 - val_loss: 15.0315
# Epoch 228/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 14.2527 - val_loss: 14.2894
# Epoch 229/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 13.3539 - val_loss: 14.5200
# Epoch 230/1000
# 646/646 [==============================] - 13s 21ms/step - loss: 15.1678 - val_loss: 13.8087
# Epoch 231/1000
# 646/646 [==============================] - 19s 29ms/step - loss: 14.2221 - val_loss: 15.0118
# Epoch 232/1000
# 646/646 [==============================] - 15s 23ms/step - loss: 14.2004 - val_loss: 15.3859
# Epoch 233/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 14.5968 - val_loss: 14.7015
# Epoch 234/1000
# 646/646 [==============================] - 14s 21ms/step - loss: 13.4269 - val_loss: 14.1882
# Epoch 235/1000
# 646/646 [==============================] - 14s 22ms/step - loss: 14.3600 - val_loss: 14.1253
# Epoch 236/1000
# 646/646 [==============================] - 19s 29ms/step - loss: 14.3241 - val_loss: 14.1017
# Epoch 237/1000
# 646/646 [==============================] - 20s 31ms/step - loss: 13.4935 - val_loss: 14.1114
# Epoch 238/1000
# 646/646 [==============================] - 17s 26ms/step - loss: 13.7949 - val_loss: 14.0749
# Epoch 239/1000
# 646/646 [==============================] - 14s 22ms/step - loss: 13.8258 - val_loss: 14.3498
# Epoch 240/1000
# 646/646 [==============================] - 19s 29ms/step - loss: 13.7802 - val_loss: 14.0056
# Epoch 241/1000
# 646/646 [==============================] - 16s 24ms/step - loss: 13.8853 - val_loss: 13.4402
# Epoch 242/1000
# 646/646 [==============================] - 18s 28ms/step - loss: 13.9913 - val_loss: 14.7962
# Epoch 243/1000
# 646/646 [==============================] - 16s 25ms/step - loss: 14.0113 - val_loss: 14.1334
# Epoch 244/1000
# 646/646 [==============================] - 20s 31ms/step - loss: 13.6260 - val_loss: 14.4410
# Epoch 245/1000
# 646/646 [==============================] - 20s 31ms/step - loss: 15.6357 - val_loss: 13.9668
# Epoch 246/1000
# 646/646 [==============================] - 18s 27ms/step - loss: 13.1973 - val_loss: 13.8912
# Epoch 247/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 14.8233 - val_loss: 14.3667
# Epoch 248/1000
# 646/646 [==============================] - 16s 25ms/step - loss: 12.9329 - val_loss: 14.7082
# Epoch 249/1000
# 646/646 [==============================] - 17s 26ms/step - loss: 13.7723 - val_loss: 13.6525
# Epoch 250/1000
# 646/646 [==============================] - 20s 30ms/step - loss: 13.3801 - val_loss: 13.5298
# Epoch 251/1000
# 646/646 [==============================] - 19s 30ms/step - loss: 13.3913 - val_loss: 13.6575
# Epoch 252/1000
# 646/646 [==============================] - 19s 29ms/step - loss: 14.1629 - val_loss: 13.4953
# Epoch 253/1000
# 646/646 [==============================] - 14s 22ms/step - loss: 13.1048 - val_loss: 13.5778
# Epoch 254/1000
# 646/646 [==============================] - 19s 30ms/step - loss: 12.9085 - val_loss: 13.9410
# Epoch 255/1000
# 646/646 [==============================] - 19s 30ms/step - loss: 13.5875 - val_loss: 13.3497
# Epoch 256/1000
# 646/646 [==============================] - 16s 25ms/step - loss: 13.6966 - val_loss: 15.7588
# Epoch 257/1000
# 646/646 [==============================] - 20s 31ms/step - loss: 13.5594 - val_loss: 13.9725
# Epoch 258/1000
# 646/646 [==============================] - 19s 30ms/step - loss: 13.3102 - val_loss: 13.0505
# Epoch 259/1000
# 646/646 [==============================] - 15s 24ms/step - loss: 13.1231 - val_loss: 13.7668
# Epoch 260/1000
# 646/646 [==============================] - 18s 28ms/step - loss: 12.3336 - val_loss: 13.9757
# Epoch 261/1000
# 646/646 [==============================] - 17s 26ms/step - loss: 13.6695 - val_loss: 13.3032
# Epoch 262/1000
# 646/646 [==============================] - 19s 29ms/step - loss: 13.2045 - val_loss: 13.6809
# Epoch 263/1000
# 646/646 [==============================] - 20s 30ms/step - loss: 13.3289 - val_loss: 14.4444
# Epoch 264/1000
# 646/646 [==============================] - 20s 31ms/step - loss: 12.4392 - val_loss: 13.1294
# Epoch 265/1000
# 646/646 [==============================] - 20s 31ms/step - loss: 13.1869 - val_loss: 13.5406
# Epoch 266/1000
# 646/646 [==============================] - 15s 23ms/step - loss: 13.1067 - val_loss: 13.5778
# Epoch 267/1000
# 646/646 [==============================] - 13s 21ms/step - loss: 12.3485 - val_loss: 13.8641
# Epoch 268/1000
# 646/646 [==============================] - 15s 24ms/step - loss: 12.8081 - val_loss: 12.6612
# Epoch 269/1000
# 646/646 [==============================] - 19s 29ms/step - loss: 13.6712 - val_loss: 13.0152
# Epoch 270/1000
# 646/646 [==============================] - 19s 30ms/step - loss: 12.6358 - val_loss: 13.2496
# Epoch 271/1000
# 646/646 [==============================] - 19s 30ms/step - loss: 13.2818 - val_loss: 14.4370
# Epoch 272/1000
# 646/646 [==============================] - 20s 31ms/step - loss: 12.2853 - val_loss: 12.9328
# Epoch 273/1000
# 646/646 [==============================] - 20s 30ms/step - loss: 12.6927 - val_loss: 13.1220
# Epoch 274/1000
# 646/646 [==============================] - 20s 31ms/step - loss: 11.9687 - val_loss: 12.7909
# Epoch 275/1000
# 646/646 [==============================] - 17s 26ms/step - loss: 11.0855 - val_loss: 13.6383
# Epoch 276/1000
# 646/646 [==============================] - 17s 27ms/step - loss: 12.8299 - val_loss: 12.8640
# Epoch 277/1000
# 646/646 [==============================] - 19s 30ms/step - loss: 11.8057 - val_loss: 12.6615
# Epoch 278/1000
# 646/646 [==============================] - 15s 24ms/step - loss: 12.4064 - val_loss: 13.6263
# Epoch 279/1000
# 646/646 [==============================] - 19s 30ms/step - loss: 11.7730 - val_loss: 14.3324
# Epoch 280/1000
# 646/646 [==============================] - 21s 32ms/step - loss: 12.4821 - val_loss: 12.7669
# Epoch 281/1000
# 646/646 [==============================] - 20s 31ms/step - loss: 13.0228 - val_loss: 14.0224
# Epoch 282/1000
# 646/646 [==============================] - 22s 34ms/step - loss: 12.8161 - val_loss: 12.5855
# Epoch 283/1000
# 646/646 [==============================] - 21s 32ms/step - loss: 11.7033 - val_loss: 13.7535
# Epoch 284/1000
# 646/646 [==============================] - 19s 30ms/step - loss: 12.8108 - val_loss: 14.5590
# Epoch 285/1000
# 646/646 [==============================] - 21s 33ms/step - loss: 14.0814 - val_loss: 12.1348
# Epoch 286/1000
# 646/646 [==============================] - 19s 30ms/step - loss: 11.8573 - val_loss: 13.0195
# Epoch 287/1000
# 646/646 [==============================] - 20s 31ms/step - loss: 12.7604 - val_loss: 12.4196
# Epoch 288/1000
# 646/646 [==============================] - 17s 27ms/step - loss: 12.1375 - val_loss: 13.3210
# Epoch 289/1000
# 646/646 [==============================] - 19s 29ms/step - loss: 12.8674 - val_loss: 12.5449
# Epoch 290/1000
# 646/646 [==============================] - 14s 22ms/step - loss: 13.0920 - val_loss: 13.3244
# Epoch 291/1000
# 646/646 [==============================] - 16s 25ms/step - loss: 12.3194 - val_loss: 12.0518
# Epoch 292/1000
# 646/646 [==============================] - 15s 23ms/step - loss: 11.1245 - val_loss: 13.1393
# Epoch 293/1000
# 646/646 [==============================] - 21s 33ms/step - loss: 11.5904 - val_loss: 12.4096
# Epoch 294/1000
# 646/646 [==============================] - 20s 31ms/step - loss: 12.1930 - val_loss: 12.8307
# Epoch 295/1000
# 646/646 [==============================] - 16s 25ms/step - loss: 11.2945 - val_loss: 13.3516
# Epoch 296/1000
# 646/646 [==============================] - 19s 29ms/step - loss: 12.4934 - val_loss: 12.6903
# Epoch 297/1000
# 646/646 [==============================] - 20s 31ms/step - loss: 13.1939 - val_loss: 12.5273
# Epoch 298/1000
# 646/646 [==============================] - 18s 28ms/step - loss: 12.1761 - val_loss: 12.5783
# Epoch 299/1000
# 646/646 [==============================] - 13s 21ms/step - loss: 11.9745 - val_loss: 11.7675
# Epoch 300/1000
# 646/646 [==============================] - 17s 26ms/step - loss: 12.2525 - val_loss: 11.8675
# Epoch 301/1000
# 646/646 [==============================] - 16s 25ms/step - loss: 11.9867 - val_loss: 12.1990
# Epoch 302/1000
# 646/646 [==============================] - 14s 22ms/step - loss: 11.7163 - val_loss: 13.2202
# Epoch 303/1000
# 646/646 [==============================] - 18s 28ms/step - loss: 12.0055 - val_loss: 12.4297
# Epoch 304/1000
# 646/646 [==============================] - 18s 29ms/step - loss: 12.6916 - val_loss: 12.1861
# Epoch 305/1000
# 646/646 [==============================] - 19s 30ms/step - loss: 11.7803 - val_loss: 12.0267
# Epoch 306/1000
# 646/646 [==============================] - 22s 34ms/step - loss: 11.7875 - val_loss: 12.7841
# Epoch 307/1000
# 646/646 [==============================] - 23s 35ms/step - loss: 12.0555 - val_loss: 12.4674
# Epoch 308/1000
# 646/646 [==============================] - 21s 33ms/step - loss: 12.3759 - val_loss: 12.4008
# Epoch 309/1000
# 646/646 [==============================] - 21s 32ms/step - loss: 12.2421 - val_loss: 12.1336
# Epoch 310/1000
# 646/646 [==============================] - 17s 26ms/step - loss: 11.0077 - val_loss: 12.1661
# Epoch 311/1000
# 646/646 [==============================] - 20s 31ms/step - loss: 11.5364 - val_loss: 12.3232
# Epoch 312/1000
# 646/646 [==============================] - 21s 33ms/step - loss: 11.6776 - val_loss: 11.7112
# Epoch 313/1000
# 646/646 [==============================] - 21s 33ms/step - loss: 11.0002 - val_loss: 13.1439
# Epoch 314/1000
# 646/646 [==============================] - 21s 32ms/step - loss: 12.2586 - val_loss: 12.5378
# Epoch 315/1000
# 646/646 [==============================] - 22s 34ms/step - loss: 11.2761 - val_loss: 12.6164
# Epoch 316/1000
# 646/646 [==============================] - 21s 32ms/step - loss: 11.7239 - val_loss: 11.8417
# Epoch 317/1000
# 646/646 [==============================] - 17s 27ms/step - loss: 11.3279 - val_loss: 13.1469
# Epoch 318/1000
# 646/646 [==============================] - 20s 31ms/step - loss: 11.3389 - val_loss: 12.5550
# Epoch 319/1000
# 646/646 [==============================] - 19s 29ms/step - loss: 12.4515 - val_loss: 11.5035
# Epoch 320/1000
# 646/646 [==============================] - 19s 30ms/step - loss: 10.9722 - val_loss: 11.8628
# Epoch 321/1000
# 646/646 [==============================] - 14s 21ms/step - loss: 12.5676 - val_loss: 13.8422
# Epoch 322/1000
# 646/646 [==============================] - 20s 31ms/step - loss: 11.4585 - val_loss: 11.7447
# Epoch 323/1000
# 646/646 [==============================] - 22s 33ms/step - loss: 12.3640 - val_loss: 12.1786
# Epoch 324/1000
# 646/646 [==============================] - 21s 33ms/step - loss: 12.5293 - val_loss: 12.2424
# Epoch 325/1000
# 646/646 [==============================] - 18s 27ms/step - loss: 12.2907 - val_loss: 11.7437
# Epoch 326/1000
# 646/646 [==============================] - 20s 31ms/step - loss: 11.3545 - val_loss: 13.8112
# Epoch 327/1000
# 646/646 [==============================] - 19s 29ms/step - loss: 11.5999 - val_loss: 12.8946
# Epoch 328/1000
# 646/646 [==============================] - 20s 31ms/step - loss: 11.7877 - val_loss: 11.4455
# Epoch 329/1000
# 646/646 [==============================] - 22s 34ms/step - loss: 11.2230 - val_loss: 11.9557
# Epoch 330/1000
# 646/646 [==============================] - 22s 35ms/step - loss: 10.9404 - val_loss: 12.9597
# Epoch 331/1000
# 646/646 [==============================] - 19s 29ms/step - loss: 12.9646 - val_loss: 12.1210
# Epoch 332/1000
# 646/646 [==============================] - 15s 23ms/step - loss: 10.7500 - val_loss: 11.8120
# Epoch 333/1000
# 646/646 [==============================] - 20s 31ms/step - loss: 12.4109 - val_loss: 12.6245
# Epoch 334/1000
# 646/646 [==============================] - 20s 31ms/step - loss: 11.9198 - val_loss: 11.8965
# Epoch 335/1000
# 646/646 [==============================] - 21s 33ms/step - loss: 10.5258 - val_loss: 12.0764
# Epoch 336/1000
# 646/646 [==============================] - 22s 35ms/step - loss: 11.1878 - val_loss: 12.7928
# Epoch 337/1000
# 646/646 [==============================] - 16s 24ms/step - loss: 11.9175 - val_loss: 11.9839
# Epoch 338/1000
# 646/646 [==============================] - 15s 23ms/step - loss: 11.6719 - val_loss: 11.6034
# Epoch 339/1000
# 646/646 [==============================] - 17s 27ms/step - loss: 10.1949 - val_loss: 11.6399
# Epoch 340/1000
# 646/646 [==============================] - 19s 30ms/step - loss: 11.5862 - val_loss: 11.4032
# Epoch 341/1000
# 646/646 [==============================] - 16s 25ms/step - loss: 11.1333 - val_loss: 11.5737
# Epoch 342/1000
# 646/646 [==============================] - 13s 21ms/step - loss: 11.2786 - val_loss: 11.1738
# Epoch 343/1000
# 646/646 [==============================] - 20s 31ms/step - loss: 11.9478 - val_loss: 11.4584
# Epoch 344/1000
# 646/646 [==============================] - 22s 34ms/step - loss: 11.3751 - val_loss: 11.2458
# Epoch 345/1000
# 646/646 [==============================] - 21s 33ms/step - loss: 11.0124 - val_loss: 12.0977
# Epoch 346/1000
# 646/646 [==============================] - 22s 34ms/step - loss: 11.2036 - val_loss: 11.9618
# Epoch 347/1000
# 646/646 [==============================] - 20s 31ms/step - loss: 11.6232 - val_loss: 11.2745
# Epoch 348/1000
# 646/646 [==============================] - 21s 32ms/step - loss: 10.6600 - val_loss: 11.1307
# Epoch 349/1000
# 646/646 [==============================] - 16s 24ms/step - loss: 11.2414 - val_loss: 11.5850
# Epoch 350/1000
# 646/646 [==============================] - 20s 30ms/step - loss: 12.6847 - val_loss: 13.5244
# Epoch 351/1000
# 646/646 [==============================] - 21s 32ms/step - loss: 11.0541 - val_loss: 11.4365
# Epoch 352/1000
# 646/646 [==============================] - 24s 38ms/step - loss: 11.2825 - val_loss: 11.5110
# Epoch 353/1000
# 646/646 [==============================] - 21s 33ms/step - loss: 11.2940 - val_loss: 12.2167
# Epoch 354/1000
# 646/646 [==============================] - 24s 36ms/step - loss: 11.1716 - val_loss: 11.6957
# Epoch 355/1000
# 646/646 [==============================] - 16s 25ms/step - loss: 10.7589 - val_loss: 10.8788
# Epoch 356/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 10.6306 - val_loss: 11.3341
# Epoch 357/1000
# 646/646 [==============================] - 22s 33ms/step - loss: 12.0006 - val_loss: 11.4612
# Epoch 358/1000
# 646/646 [==============================] - 25s 38ms/step - loss: 10.4136 - val_loss: 10.9334
# Epoch 359/1000
# 646/646 [==============================] - 22s 33ms/step - loss: 11.0791 - val_loss: 12.2816
# Epoch 360/1000
# 646/646 [==============================] - 24s 38ms/step - loss: 11.2474 - val_loss: 11.5533
# Epoch 361/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 11.8049 - val_loss: 11.7784
# Epoch 362/1000
# 646/646 [==============================] - 22s 33ms/step - loss: 10.7719 - val_loss: 11.4968
# Epoch 363/1000
# 646/646 [==============================] - 22s 33ms/step - loss: 11.0242 - val_loss: 11.9268
# Epoch 364/1000
# 646/646 [==============================] - 23s 36ms/step - loss: 10.4852 - val_loss: 11.5378
# Epoch 365/1000
# 646/646 [==============================] - 22s 34ms/step - loss: 10.9226 - val_loss: 11.2237
# Epoch 366/1000
# 646/646 [==============================] - 23s 35ms/step - loss: 11.4993 - val_loss: 11.4454
# Epoch 367/1000
# 646/646 [==============================] - 22s 34ms/step - loss: 10.4590 - val_loss: 11.0758
# Epoch 368/1000
# 646/646 [==============================] - 23s 35ms/step - loss: 11.0735 - val_loss: 10.5228
# Epoch 369/1000
# 646/646 [==============================] - 22s 34ms/step - loss: 10.7019 - val_loss: 10.9643
# Epoch 370/1000
# 646/646 [==============================] - 22s 34ms/step - loss: 10.6142 - val_loss: 10.6819
# Epoch 371/1000
# 646/646 [==============================] - 21s 33ms/step - loss: 10.7241 - val_loss: 11.0524
# Epoch 372/1000
# 646/646 [==============================] - 22s 33ms/step - loss: 10.4855 - val_loss: 11.5008
# Epoch 373/1000
# 646/646 [==============================] - 22s 34ms/step - loss: 10.7509 - val_loss: 11.2186
# Epoch 374/1000
# 646/646 [==============================] - 23s 35ms/step - loss: 9.9276 - val_loss: 11.0873
# Epoch 375/1000
# 646/646 [==============================] - 22s 33ms/step - loss: 11.3756 - val_loss: 11.3090
# Epoch 376/1000
# 646/646 [==============================] - 22s 34ms/step - loss: 10.3588 - val_loss: 10.5811
# Epoch 377/1000
# 646/646 [==============================] - 22s 34ms/step - loss: 10.5068 - val_loss: 10.9020
# Epoch 378/1000
# 646/646 [==============================] - 22s 33ms/step - loss: 10.4156 - val_loss: 11.1705
# Epoch 379/1000
# 646/646 [==============================] - 22s 34ms/step - loss: 10.9652 - val_loss: 10.8722
# Epoch 380/1000
# 646/646 [==============================] - 22s 34ms/step - loss: 11.1706 - val_loss: 11.8438
# Epoch 381/1000
# 646/646 [==============================] - 21s 33ms/step - loss: 10.7204 - val_loss: 11.3931
# Epoch 382/1000
# 646/646 [==============================] - 22s 33ms/step - loss: 10.5831 - val_loss: 11.8472
# Epoch 383/1000
# 646/646 [==============================] - 22s 34ms/step - loss: 10.8462 - val_loss: 11.4410
# Epoch 384/1000
# 646/646 [==============================] - 22s 34ms/step - loss: 10.2385 - val_loss: 11.2270
# Epoch 385/1000
# 646/646 [==============================] - 22s 33ms/step - loss: 10.5621 - val_loss: 11.7571
# Epoch 386/1000
# 646/646 [==============================] - 22s 34ms/step - loss: 10.9638 - val_loss: 11.9027
# Epoch 387/1000
# 646/646 [==============================] - 21s 32ms/step - loss: 10.3515 - val_loss: 10.0723
# Epoch 388/1000
# 646/646 [==============================] - 21s 33ms/step - loss: 9.8372 - val_loss: 10.8197
# Epoch 389/1000
# 646/646 [==============================] - 21s 32ms/step - loss: 10.8060 - val_loss: 11.1512
# Epoch 390/1000
# 646/646 [==============================] - 22s 33ms/step - loss: 10.8346 - val_loss: 11.6588
# Epoch 391/1000
# 646/646 [==============================] - 21s 32ms/step - loss: 10.2412 - val_loss: 10.7670
# Epoch 392/1000
# 646/646 [==============================] - 21s 32ms/step - loss: 10.0897 - val_loss: 10.8141
# Epoch 393/1000
# 646/646 [==============================] - 20s 31ms/step - loss: 9.6415 - val_loss: 11.3250
# Epoch 394/1000
# 646/646 [==============================] - 19s 29ms/step - loss: 10.8888 - val_loss: 11.4692
# Epoch 395/1000
# 646/646 [==============================] - 15s 24ms/step - loss: 11.1983 - val_loss: 10.7299
# Epoch 396/1000
# 646/646 [==============================] - 19s 30ms/step - loss: 10.8077 - val_loss: 10.5298
# Epoch 397/1000
# 646/646 [==============================] - 21s 32ms/step - loss: 10.2180 - val_loss: 10.8809
# Epoch 398/1000
# 646/646 [==============================] - 21s 33ms/step - loss: 10.1478 - val_loss: 10.7844
# Epoch 399/1000
# 646/646 [==============================] - 21s 33ms/step - loss: 10.2852 - val_loss: 11.4278
# Epoch 400/1000
# 646/646 [==============================] - 21s 32ms/step - loss: 11.5887 - val_loss: 10.7025
# Epoch 401/1000
# 646/646 [==============================] - 21s 33ms/step - loss: 10.8877 - val_loss: 11.4703
# Epoch 402/1000
# 646/646 [==============================] - 22s 33ms/step - loss: 10.0629 - val_loss: 11.2415
# Epoch 403/1000
# 646/646 [==============================] - 21s 32ms/step - loss: 10.4821 - val_loss: 11.0930
# Epoch 404/1000
# 646/646 [==============================] - 22s 33ms/step - loss: 10.3027 - val_loss: 12.6734
# Epoch 405/1000
# 646/646 [==============================] - 21s 32ms/step - loss: 10.1308 - val_loss: 12.8486
# Epoch 406/1000
# 646/646 [==============================] - 21s 33ms/step - loss: 11.2709 - val_loss: 10.1903
# Epoch 407/1000
# 646/646 [==============================] - 21s 32ms/step - loss: 9.7653 - val_loss: 10.7467
# Epoch 408/1000
# 646/646 [==============================] - 22s 34ms/step - loss: 9.5185 - val_loss: 10.7385
# Epoch 409/1000
# 646/646 [==============================] - 21s 32ms/step - loss: 10.0031 - val_loss: 10.9971
# Epoch 410/1000
# 646/646 [==============================] - 21s 33ms/step - loss: 9.3685 - val_loss: 11.6574
# Epoch 411/1000
# 646/646 [==============================] - 22s 34ms/step - loss: 10.9857 - val_loss: 11.1134
# Epoch 412/1000
# 646/646 [==============================] - 21s 33ms/step - loss: 10.2198 - val_loss: 11.0048
# Epoch 413/1000
# 646/646 [==============================] - 21s 32ms/step - loss: 10.3278 - val_loss: 10.8789
# Epoch 414/1000
# 646/646 [==============================] - 16s 25ms/step - loss: 11.0409 - val_loss: 10.7817
# Epoch 415/1000
# 646/646 [==============================] - 17s 26ms/step - loss: 10.3944 - val_loss: 11.2683
# Epoch 416/1000
# 646/646 [==============================] - 19s 30ms/step - loss: 10.1914 - val_loss: 11.6399
# Epoch 417/1000
# 646/646 [==============================] - 20s 31ms/step - loss: 11.2216 - val_loss: 10.9298
# Epoch 418/1000
# 646/646 [==============================] - 22s 34ms/step - loss: 9.9773 - val_loss: 11.1616
# Epoch 419/1000
# 646/646 [==============================] - 22s 33ms/step - loss: 10.2285 - val_loss: 11.9201
# Epoch 420/1000
# 646/646 [==============================] - 22s 33ms/step - loss: 10.2478 - val_loss: 10.4460
# Epoch 421/1000
# 646/646 [==============================] - 21s 33ms/step - loss: 9.5869 - val_loss: 10.7941
# Epoch 422/1000
# 646/646 [==============================] - 21s 32ms/step - loss: 10.8332 - val_loss: 11.0268
# Epoch 423/1000
# 646/646 [==============================] - 21s 33ms/step - loss: 11.0364 - val_loss: 11.2089
# Epoch 424/1000
# ...
# Epoch 851/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 7.1980 - val_loss: 8.3536
# Epoch 852/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 7.6996 - val_loss: 9.9365
# Epoch 853/1000
# 646/646 [==============================] - 15s 24ms/step - loss: 8.1416 - val_loss: 8.2472
# Epoch 854/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 7.9784 - val_loss: 9.3634
# Epoch 855/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 7.9558 - val_loss: 7.9062
# Epoch 856/1000
# 646/646 [==============================] - 17s 26ms/step - loss: 6.8776 - val_loss: 8.9902
# Epoch 857/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 7.5535 - val_loss: 8.0807
# Epoch 858/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 8.0487 - val_loss: 8.2545
# Epoch 859/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 7.9546 - val_loss: 8.0155
# Epoch 860/1000
# 646/646 [==============================] - 24s 38ms/step - loss: 7.3512 - val_loss: 8.7817
# Epoch 861/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 7.5998 - val_loss: 7.8954
# Epoch 862/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 7.4772 - val_loss: 8.4941
# Epoch 863/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 7.8227 - val_loss: 8.7795
# Epoch 864/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 6.9302 - val_loss: 8.1969
# Epoch 865/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 7.7843 - val_loss: 9.0181
# Epoch 866/1000
# 646/646 [==============================] - 22s 33ms/step - loss: 8.0732 - val_loss: 9.5960
# Epoch 867/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 7.6641 - val_loss: 8.3290
# Epoch 868/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 6.9980 - val_loss: 7.8416
# Epoch 869/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 7.5666 - val_loss: 7.8549
# Epoch 870/1000
# 646/646 [==============================] - 14s 21ms/step - loss: 7.8364 - val_loss: 7.9320
# Epoch 871/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 7.3627 - val_loss: 9.0645
# Epoch 872/1000
# 646/646 [==============================] - 13s 19ms/step - loss: 8.2820 - val_loss: 9.7609
# Epoch 873/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 8.8873 - val_loss: 8.3062
# Epoch 874/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 7.3154 - val_loss: 8.2023
# Epoch 875/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 7.0776 - val_loss: 8.3019
# Epoch 876/1000
# 646/646 [==============================] - 19s 30ms/step - loss: 7.5895 - val_loss: 8.6941
# Epoch 877/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 7.2283 - val_loss: 8.1453
# Epoch 878/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 7.6840 - val_loss: 8.9040
# Epoch 879/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 7.7289 - val_loss: 8.3618
# Epoch 880/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 7.3137 - val_loss: 7.9257
# Epoch 881/1000
# 646/646 [==============================] - 13s 19ms/step - loss: 8.2132 - val_loss: 8.7264
# Epoch 882/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 7.0807 - val_loss: 8.5250
# Epoch 883/1000
# 646/646 [==============================] - 13s 19ms/step - loss: 7.2954 - val_loss: 7.4854
# Epoch 884/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 7.5579 - val_loss: 8.4259
# Epoch 885/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 7.9194 - val_loss: 7.6758
# Epoch 886/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 6.9701 - val_loss: 7.9425
# Epoch 887/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 7.4991 - val_loss: 8.8203
# Epoch 888/1000
# 646/646 [==============================] - 13s 19ms/step - loss: 7.2133 - val_loss: 8.6020
# Epoch 889/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 7.0889 - val_loss: 8.5691
# Epoch 890/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 7.7641 - val_loss: 7.7861
# Epoch 891/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 7.2200 - val_loss: 8.2823
# Epoch 892/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 8.0028 - val_loss: 8.1023
# Epoch 893/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 7.3732 - val_loss: 7.8078
# Epoch 894/1000
# 646/646 [==============================] - 13s 19ms/step - loss: 6.7933 - val_loss: 7.8244
# Epoch 895/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 7.2398 - val_loss: 8.2429
# Epoch 896/1000
# 646/646 [==============================] - 18s 28ms/step - loss: 6.9633 - val_loss: 7.5236
# Epoch 897/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 7.2605 - val_loss: 7.9590
# Epoch 898/1000
# 646/646 [==============================] - 13s 19ms/step - loss: 7.5456 - val_loss: 9.0063
# Epoch 899/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 7.8361 - val_loss: 8.1480
# Epoch 900/1000
# 646/646 [==============================] - 13s 19ms/step - loss: 7.1596 - val_loss: 9.6246
# Epoch 901/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 7.9775 - val_loss: 8.4701
# Epoch 902/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 7.9338 - val_loss: 8.9330
# Epoch 903/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 7.4409 - val_loss: 7.9718
# Epoch 904/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 6.5617 - val_loss: 10.1188
# Epoch 905/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 8.1840 - val_loss: 8.0778
# Epoch 906/1000
# 646/646 [==============================] - 13s 19ms/step - loss: 6.6687 - val_loss: 8.3299
# Epoch 907/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 7.9056 - val_loss: 7.8796
# Epoch 908/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 6.8002 - val_loss: 7.8050
# Epoch 909/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 7.1852 - val_loss: 7.7322
# Epoch 910/1000
# 646/646 [==============================] - 13s 19ms/step - loss: 7.3390 - val_loss: 9.3246
# Epoch 911/1000
# 646/646 [==============================] - 13s 19ms/step - loss: 8.1422 - val_loss: 7.6433
# Epoch 912/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 6.9618 - val_loss: 9.1213
# Epoch 913/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 7.8551 - val_loss: 7.81615
# Epoch 914/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 7.0025 - val_loss: 8.1909
# Epoch 915/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 7.4253 - val_loss: 8.8585
# Epoch 916/1000
# 646/646 [==============================] - 14s 21ms/step - loss: 7.5328 - val_loss: 7.9675
# Epoch 917/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 7.2386 - val_loss: 8.1094
# Epoch 918/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 7.4522 - val_loss: 11.7245
# Epoch 919/1000
# 646/646 [==============================] - 14s 22ms/step - loss: 8.1326 - val_loss: 8.3101
# Epoch 920/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 6.8553 - val_loss: 8.5153
# Epoch 921/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 7.3828 - val_loss: 8.4380
# Epoch 922/1000
# 646/646 [==============================] - 21s 32ms/step - loss: 8.2157 - val_loss: 8.5885
# Epoch 923/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 7.5174 - val_loss: 7.3155
# Epoch 924/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 7.0275 - val_loss: 7.6560
# Epoch 925/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 6.5660 - val_loss: 8.7398
# Epoch 926/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 7.0383 - val_loss: 8.0460
# Epoch 927/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 7.6578 - val_loss: 9.1945
# Epoch 928/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 7.3097 - val_loss: 7.7697
# Epoch 929/1000
# 646/646 [==============================] - 13s 19ms/step - loss: 7.2495 - val_loss: 7.8347
# Epoch 930/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 6.7508 - val_loss: 7.4615
# Epoch 931/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 7.2940 - val_loss: 7.9108
# Epoch 932/1000
# 646/646 [==============================] - 18s 27ms/step - loss: 7.0456 - val_loss: 10.4511
# Epoch 933/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 7.3482 - val_loss: 9.2918
# Epoch 934/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 7.3051 - val_loss: 10.3492
# Epoch 935/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 8.7988 - val_loss: 8.3711
# Epoch 936/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 7.6054 - val_loss: 8.0201
# Epoch 937/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 7.1115 - val_loss: 8.0671
# Epoch 938/1000
# 646/646 [==============================] - 24s 38ms/step - loss: 6.7701 - val_loss: 8.2837
# Epoch 939/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 7.5586 - val_loss: 19.6768
# Epoch 940/1000
# 646/646 [==============================] - 25s 38ms/step - loss: 9.1563 - val_loss: 7.9049
# Epoch 941/1000
# 646/646 [==============================] - 26s 40ms/step - loss: 6.6303 - val_loss: 9.9985
# Epoch 942/1000
# 646/646 [==============================] - 26s 40ms/step - loss: 7.4423 - val_loss: 9.0929
# Epoch 943/1000
# 646/646 [==============================] - 24s 36ms/step - loss: 6.9754 - val_loss: 8.5215
# Epoch 944/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 8.3965 - val_loss: 9.0731
# Epoch 945/1000
# 646/646 [==============================] - 26s 41ms/step - loss: 7.8267 - val_loss: 7.6664
# Epoch 946/1000
# 646/646 [==============================] - 25s 38ms/step - loss: 6.9375 - val_loss: 11.0609
# Epoch 947/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 7.6256 - val_loss: 7.9720
# Epoch 948/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 7.4448 - val_loss: 8.4152
# Epoch 949/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 8.1798 - val_loss: 7.5440
# Epoch 950/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 7.1283 - val_loss: 7.9046
# Epoch 951/1000
# 646/646 [==============================] - 24s 38ms/step - loss: 7.3338 - val_loss: 9.1140
# Epoch 952/1000
# 646/646 [==============================] - 25s 38ms/step - loss: 7.3195 - val_loss: 8.3197
# Epoch 953/1000
# 646/646 [==============================] - 25s 39ms/step - loss: 7.2215 - val_loss: 8.3158
# Epoch 954/1000
# 646/646 [==============================] - 24s 37ms/step - loss: 7.2745 - val_loss: 8.6454
# Epoch 955/1000
# 646/646 [==============================] - 24s 36ms/step - loss: 7.0474 - val_loss: 7.5303
# Epoch 956/1000
# 646/646 [==============================] - 25s 38ms/step - loss: 7.4428 - val_loss: 7.6388
# Epoch 957/1000
# 646/646 [==============================] - 18s 27ms/step - loss: 8.8560 - val_loss: 7.5141
# Epoch 958/1000
# 646/646 [==============================] - 13s 19ms/step - loss: 7.1178 - val_loss: 7.8743
# Epoch 959/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 7.1492 - val_loss: 9.1694
# Epoch 960/1000
# 646/646 [==============================] - 13s 19ms/step - loss: 7.6616 - val_loss: 8.1832
# Epoch 961/1000
# 646/646 [==============================] - 13s 19ms/step - loss: 7.1484 - val_loss: 9.4267
# Epoch 962/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 7.3891 - val_loss: 7.8182
# Epoch 963/1000
# 646/646 [==============================] - 12s 18ms/step - loss: 6.7731 - val_loss: 7.6346
# Epoch 964/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 7.2989 - val_loss: 8.1475
# Epoch 965/1000
# 646/646 [==============================] - 13s 19ms/step - loss: 7.1634 - val_loss: 7.7786
# Epoch 966/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 7.0441 - val_loss: 8.7296
# Epoch 967/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 7.8886 - val_loss: 8.0611
# Epoch 968/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 7.3856 - val_loss: 9.4015
# Epoch 969/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 9.2730 - val_loss: 9.0949
# Epoch 970/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 7.8933 - val_loss: 9.0122
# Epoch 971/1000
# 646/646 [==============================] - 13s 19ms/step - loss: 7.4030 - val_loss: 7.9810
# Epoch 972/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 7.1548 - val_loss: 8.8050
# Epoch 973/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 7.1622 - val_loss: 8.4138
# Epoch 974/1000
# 646/646 [==============================] - 13s 19ms/step - loss: 7.2535 - val_loss: 8.7060
# Epoch 975/1000
# 646/646 [==============================] - 13s 19ms/step - loss: 7.1601 - val_loss: 8.5127
# Epoch 976/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 7.0009 - val_loss: 8.4430
# Epoch 977/1000
# 646/646 [==============================] - 21s 33ms/step - loss: 7.1976 - val_loss: 8.1666
# Epoch 978/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 8.0404 - val_loss: 8.1594
# Epoch 979/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 6.8305 - val_loss: 8.3061
# Epoch 980/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 7.3772 - val_loss: 7.9021
# Epoch 981/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 7.2021 - val_loss: 7.6014
# Epoch 982/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 7.2995 - val_loss: 8.1672
# Epoch 983/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 6.7601 - val_loss: 8.8606
# Epoch 984/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 7.9512 - val_loss: 11.7854
# Epoch 985/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 8.2465 - val_loss: 8.0511
# Epoch 986/1000
# 646/646 [==============================] - 13s 19ms/step - loss: 7.9450 - val_loss: 8.1052
# Epoch 987/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 8.3288 - val_loss: 7.6361
# Epoch 988/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 7.0340 - val_loss: 15.1909
# Epoch 989/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 7.8439 - val_loss: 7.5877
# Epoch 990/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 7.3715 - val_loss: 7.6251
# Epoch 991/1000
# 646/646 [==============================] - 13s 21ms/step - loss: 7.3211 - val_loss: 7.0916
# Epoch 992/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 7.2517 - val_loss: 7.9125
# Epoch 993/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 6.6713 - val_loss: 8.0287
# Epoch 994/1000
# 646/646 [==============================] - 14s 21ms/step - loss: 7.2504 - val_loss: 7.8703
# Epoch 995/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 7.4667 - val_loss: 8.2420
# Epoch 996/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 7.5599 - val_loss: 7.4893
# Epoch 997/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 6.8191 - val_loss: 7.5293
# Epoch 998/1000
# 646/646 [==============================] - 12s 19ms/step - loss: 8.4776 - val_loss: 7.7909
# Epoch 999/1000
# 646/646 [==============================] - 13s 20ms/step - loss: 6.7932 - val_loss: 8.3602
# Epoch 1000/1000
# 646/646 [==============================] - 14s 21ms/step - loss: 7.9673 - val_loss: 7.1050
# Text(0.5, 0, 'Epoch')

# %%
model.save("./models_log" + "/" + "mfcc_LSTM_autoencoder_spcup.h5")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5581ed9cc6c6> in <module>
# ----> 1 model.save("./models_log" + "/" + "mfcc_LSTM_autoencoder_spcup.h5")
#
# NameError: name 'model' is not defined

# %%
new_m = tf.keras.models.load_model('./models_log/LSTM_autoencoder_spcup.h5')
new_m.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_1 (LSTM)             (None, 16, 64)            33024
# _________________________________________________________________
# encoder_2 (LSTM)             (None, 16, 32)            12416
# _________________________________________________________________
# encoder_3 (LSTM)             (None, 16, 16)            3136
# _________________________________________________________________
# decoder_1 (LSTM)             (None, 16, 16)            2112
# _________________________________________________________________
# decoder_2 (LSTM)             (None, 16, 32)            6272
# _________________________________________________________________
# decoder_3 (LSTM)             (None, 16, 64)            24832
# _________________________________________________________________
# time_distributed (TimeDistri (None, 16, 64)            4160
# =================================================================
# Total params: 85,952
# Trainable params: 85,952
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(test_t.shape)
print(mse_test.shape)
print(mse_test[0])
# Out:
# (6460, 32, 64)
# (6460, 64)
# [-7.43468031e-02  5.08537367e-02 -3.36262167e-01  2.56908864e-01
#   3.54959726e-01  1.37092590e+00 -1.62134445e+00 -3.90718699e-01
#   7.45697618e-01 -6.87825441e-01 -1.03341126e+00  1.08183995e-01
#  -2.94540226e-02  9.03362155e-01  4.82404768e-01 -2.38186613e-01
#  -6.63390338e-01  2.63847947e-01 -5.57700694e-01 -6.81811213e-01
#   3.05552110e-02 -1.37812406e-01  8.33552778e-02 -3.63388024e-02
#  -7.60065615e-02  1.04776271e-01  1.39151245e-01 -1.92988694e-01
#  -1.49630278e-03  1.99910074e-01  6.27901971e-01  9.13563192e-01
#   3.49049307e-02  1.12823419e-01  2.54184484e-01 -3.11305095e-02
#  -1.04529373e-02  8.79824683e-02  1.92759916e-01  6.83709309e-02
#   2.95519382e-01  2.47543842e-01  2.03087956e-01  1.41035959e-01
#   2.16236979e-01  1.15204543e-01  4.18784842e-02  3.32454666e-02
#   2.29063760e-02  2.86915191e-02  3.49419974e-02  3.32040340e-02
#  -8.75356048e-03 -2.19964646e-02 -1.49305817e-02 -6.00019991e-02
#  -7.00854063e-02 -5.55811934e-02  1.44210123e-02  1.19429259e-02
#  -1.88399300e-01 -9.86118764e-02  1.52840927e-01 -8.55997801e-02]

# %%
# data_or= []
# labels_or = []
# def order_data(data, labels):
#     data = np.array(data)
#     for i in range(5):
# #         print(labels == i)
#         data_or.append(data[labels == i])
#         labels_or.append(labels[labels==i])
#     return np.array(data_or).reshape((1,-1))[0], np.array(labels_or).reshape((1,-1))[0]


# known_volume_path = 'C:/Users/GJ/Desktop/연구실/2022SPCUP/WAV_Ordered train set'
# X_train_path, y_train_raw = order_data(known_path, known_labels)

# known_path, known_labels = file_path_list(known_volume_path)

# unknown_path, unknown_labels = file_path_list(unknown_volume_path)


# X_train_path, y_train_raw = order_data(known_path, known_labels)

# n_mels = 64
# n = -1
# train = classes.data(X_train_path[:n],y_train_raw[:n],n_mels=n_mels, known = True)

# # test = classes.data(X_test_path[:n],y_test_raw[:n], n_mels=n_mels, known = True)

# unseen =data(unknown_path[:n],unknown_labels[:n], n_mels=n_mels, known = False)


# train_t = train.X_split.transpose((0, 2, 1))
# # test_t = test.X_split.transpose((0, 2, 1))
# unseen_t = unseen.X_split.transpose((0, 2, 1))

# %%
print(len(X_train_path))
# Out:
# 4000

# %%
from scipy.stats import mode
test_x_predictions = model.predict(test_t)
unseen_x_predictions = model.predict(unseen_t)
print(test_x_predictions.shape)
print(unseen_x_predictions.shape)
# Out:
# (6460, 32, 64)
# (6275, 32, 64)

# %%
sum_all_mse = np.sum(all_mse)

# %%
print(test_x_predictions.shape)
# mse_test = np.sqrt(np.mean(np.power(test_t - test_x_predictions, 2), axis=2))
mse_test = np.sum(np.power(test_t - test_x_predictions, 1), axis=1)
# mse_test = np.sum(np.sum(np.power(test_t - test_x_predictions, 1), axis=1),axis =1 )

print(mse_test.shape)

print(unseen_x_predictions.shape)
# mse_unseen = np.sqrt(np.mean(np.power(unseen_t - unseen_x_predictions, 2), axis=2))
mse_unseen = np.sum(np.power(unseen_t - unseen_x_predictions, 1), axis=1)
# mse_unseen = np.sum(np.sum(np.power(unseen_t - unseen_x_predictions, 1), axis=1),axis =1 )

print(mse_unseen.shape)
# print((test.labels == 0).shape)

all_mse = np.concatenate((mse_test[test.y_split == 0],mse_test[test.y_split == 1],mse_test[test.y_split == 2],
                          mse_test[test.y_split == 3],mse_test[test.y_split == 4],mse_unseen),axis = 0)
print('all_mse.shape : ', all_mse.shape)

for i in range(all_mse.shape[1]):
    plt.subplot()
    plt.plot(all_mse[:,i])
    plt.plot(all_mse[:6460,i])
    
    plt.show()
    
# plt.subplot()
# plt.plot(all_mse)
# plt.plot(all_mse[:6460])
# plt.show()
# Out:
# (6460, 32, 64)
# (6460, 64)
# (6275, 32, 64)
# (6275, 64)
# all_mse.shape :  (12735, 64)

# %%
for i in range(all_mse.shape[1]):
    plt.subplot()
    plt.plot(all_mse[:,i])
    plt.show()

# %%
test_x_predictions.shape
# Out:
# (6460, 32, 64)

# %%
plt.plot(all_mse)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Conv2D, MaxPool2D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint

print((train.X_split.shape))
model = Sequential()
'''
#model 1
model.add(layers.BatchNormalization(input_shape=(X_train.shape[1:])))
model.add(layers.Conv2D(filters=64, kernel_size=(5, 5), padding="same", activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(filters=128, kernel_size=(5, 5), padding="same", activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(filters=64, kernel_size=(5, 5), padding="same", activation='relu'))
model.add(MaxPool2D(pool_size=(5, 5)))
model.add(Flatten())
model.add(layers.Dense(5, activation='softmax'))
'''
#model 2
model.add(layers.BatchNormalization(input_shape=(train.X_split)))
model.add(layers.Conv2D(filters=16, kernel_size=(5, 5), padding="same", activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(filters=32, kernel_size=(5, 5), padding="same", activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(filters=64, kernel_size=(5, 5), padding="same", activation='relu'))
model.add(MaxPool2D(pool_size=(5, 5)))
model.add(Flatten())
model.add(layers.Dense(5, activation=None))
model.add(layers.Activation('softmax'))

model.summary()
# Out:
# (68, 64, 32)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-f438fa428beb> in <module>
#      19 '''
#      20 #model 2
# ---> 21 model.add(layers.BatchNormalization(input_shape=(train.X_split)))
#      22 model.add(layers.Conv2D(filters=16, kernel_size=(5, 5), padding="same", activation='relu'))
#      23 model.add(layers.BatchNormalization())
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\training\tracking\base.py in _method_wrapper(self, *args, **kwargs)
#     515     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     516     try:
# --> 517       result = method(self, *args, **kwargs)
#     518     finally:
#     519       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\engine\sequential.py in add(self, layer)
#     201         if batch_shape:
#     202           # Instantiate an input layer.
# --> 203           x = input_layer.Input(
#     204               batch_shape=batch_shape, dtype=dtype, name=layer.name + '_input')
#     205           # This will build the current layer
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\engine\input_layer.py in Input(shape, batch_size, name, dtype, sparse, tensor, ragged, **kwargs)
#     307     input_layer_config.update(
#     308         {'batch_size': batch_size, 'input_shape': shape})
# --> 309   input_layer = InputLayer(**input_layer_config)
#     310
#     311   # Return tensor including `_keras_history`.
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\engine\input_layer.py in __init__(self, input_shape, batch_size, dtype, input_tensor, sparse, name, ragged, **kwargs)
#     153       graph = backend.get_graph()
#     154       with graph.as_default():
# --> 155         input_tensor = backend.placeholder(
#     156             shape=batch_input_shape,
#     157             dtype=dtype,
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\backend.py in placeholder(shape, ndim, dtype, sparse, name, ragged)
#    1244       x = keras_tensor.RaggedKerasTensor(spec, name=name)
#    1245     else:
# -> 1246       spec = tensor_spec.TensorSpec(
#    1247           shape=shape, dtype=dtype, name=name)
#    1248       x = keras_tensor.KerasTensor(spec, name=name)
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\framework\tensor_spec.py in __init__(self, shape, dtype, name)
#      49         not convertible to a `tf.DType`.
#      50     """
# ---> 51     self._shape = tensor_shape.TensorShape(shape)
#      52     try:
#      53       self._shape_tuple = tuple(self.shape.as_list())
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\framework\tensor_shape.py in __init__(self, dims)
#     756     """
#     757     if isinstance(dims, (tuple, list)):  # Most common case.
# --> 758       self._dims = [Dimension(d) for d in dims]
#     759     elif dims is None:
#     760       self._dims = None
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\framework\tensor_shape.py in <listcomp>(.0)
#     756     """
#     757     if isinstance(dims, (tuple, list)):  # Most common case.
# --> 758       self._dims = [Dimension(d) for d in dims]
#     759     elif dims is None:
#     760       self._dims = None
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\framework\tensor_shape.py in __init__(self, value)
#     199         # int(...) compensates for the int/long dichotomy on Python 2.X.
#     200         # TODO(b/143206389): Remove once we fully migrate to 3.X.
# --> 201         self._value = int(value.__index__())
#     202       except AttributeError:
#     203         six.raise_from(
#
# TypeError: only integer scalar arrays can be converted to a scalar index
