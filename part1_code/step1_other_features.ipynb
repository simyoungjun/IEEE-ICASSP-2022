# %%
# %load_ext autoreload
# %autoreload 2
from class_new import *

# %%
# import import_ipynb

import sys
sys.path.append('C:/Users/GJ/PycharmProjects/2022SPCUP')


from class_new import *
import class_new
import importlib
importlib.reload(class_new)

import tensorflow as tf
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, recall_score, accuracy_score, precision_score

from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout, UpSampling2D, Input, Convolution2D, Reshape

known_volume_path = 'C:/Users/GJ/Desktop/연구실/2022SPCUP/spcup_2022_training_part1'
unknown_volume_path = './spcup_2022_unseen'




rs = 10
known_path, known_labels = part1_file_path_list(known_volume_path,True)
unknown_path, unknown_labels = part1_file_path_list(unknown_volume_path,False)

# print(known_path)
print(known_labels.shape)
print(unknown_labels.shape)

all_path = np.concatenate((known_path,unknown_path),axis = 0)
all_labels = np.concatenate((known_labels,unknown_labels),axis = 0)
print(all_labels.shape)


##train set
# print('raw train_set_num :',len(labels))
# X_train_path, X_test_path, y_train_raw, y_test_raw = train_test_split(all_path,
#                                                                       all_labels, test_size=0.2,
#                                                                       stratify = all_labels, random_state=rs)


n_mels = 64
samplint_rate = 16000
# train = classes.data(X_train_path, y_train_raw, n_mels=n_mels, known = True)
# # X_train,y_train = train.extract_mel(sampling_rate,n_mels)
#
# test = classes.data(X_test_path, y_test_raw, n_mels=n_mels, known = True)
# # X_test,y_test = test.extract_mel(sampling_rate,n_mels)
#
# unseen = data(unknown_path, unknown_labels, n_mels=n_mels, known = False)

# n = -1
# train = data(X_train_path[:n],y_train_raw[:n],n_mels=n_mels, known = True)

# test = data(X_test_path[:n],y_test_raw[:n], n_mels=n_mels, known = True)




train = data(all_path,all_labels,n_mels=n_mels, known = True)

# test = data(X_test_path,y_test_raw, n_mels=n_mels, known = True)

train.extract_mel()
# test.extract_mel()



train.reshape_data()
# test.reshape_data()
# Out:
# (5000,)
# (1000,)
# (6000,)
# X_train.shape :  (38576, 64, 32, 1)
# y_train.shape (38576, 6)

# %%
import pickle
with open('part1_label6_train.p','wb') as f:
    pickle.dump(train,f)
with open('part1_label6_test.p','wb') as f:
    pickle.dump(test,f)

    
    
# with open("part1_label6_train.p", 'rb') as f:
#     train = pickle.load(f)
# with open("part1_label6_test.p", 'rb') as f:
#     test = pickle.load(f)

# %%
X_train = train.X_reshaped
X_test = test.X_reshaped
y_train = train.y_reshaped
y_test = test.y_reshaped
print(y_train.shape)
# Out:
# (30878, 6)

# %%
X_train = train.X_reshaped
X_test = test.X_reshaped
y_train = train.y_reshaped
y_test = test.y_reshaped

for n_mels in [64]:
    for hop_length in [1024]:
        for n_fft in [2048]:
            from tensorflow.keras.models import Sequential
            from tensorflow.keras.layers import Flatten, Conv2D, MaxPool2D
            from tensorflow.keras.callbacks import EarlyStopping
            from tensorflow.keras.callbacks import ModelCheckpoint

            print((X_train.shape[1:]))
            model = Sequential()
            '''
            #model 1
            model.add(layers.BatchNormalization(input_shape=(X_train.shape[1:])))
            model.add(layers.Conv2D(filters=64, kernel_size=(5, 5), padding="same", activation='relu'))
            model.add(layers.BatchNormalization())
            model.add(layers.Conv2D(filters=128, kernel_size=(5, 5), padding="same", activation='relu'))
            model.add(layers.BatchNormalization())
            model.add(layers.Conv2D(filters=64, kernel_size=(5, 5), padding="same", activation='relu'))
            model.add(MaxPool2D(pool_size=(5, 5)))
            model.add(Flatten())
            model.add(layers.Dense(5, activation='softmax'))
            '''
            #model 2
            model.add(layers.BatchNormalization(input_shape=(X_train.shape[1:])))
            model.add(layers.Conv2D(filters=16, kernel_size=(5, 5), padding="same", activation='relu'))
            model.add(layers.BatchNormalization())
            model.add(layers.Conv2D(filters=32, kernel_size=(5, 5), padding="same", activation='relu'))
            model.add(layers.BatchNormalization())
            model.add(layers.Conv2D(filters=64, kernel_size=(5, 5), padding="same", activation='relu'))
            model.add(MaxPool2D(pool_size=(5, 5)))
            model.add(Flatten())
            model.add(layers.Dense(6, activation=None))
            model.add(layers.Activation('softmax'))


            # 모델 컴파일
            model.compile(optimizer='adam',
                          loss='categorical_crossentropy',
                          metrics=['accuracy'])


            callbacks = [EarlyStopping(monitor='val_loss', min_delta=0, patience=100, mode='auto',restore_best_weights=True), 
                         ModelCheckpoint(filepath="./models_log" + "/" +str(n_mels)+"_"+str(hop_length)+"_"+ str(rs) + "_"
                                         + "mel_label_6_model.h5",
                                         monitor='val_loss', verbose=0, save_best_only=True)]

            classifier = model.fit(X_train,
                                   y_train,
                                   epochs=1000,
                                   batch_size=128, callbacks=callbacks,
                                   validation_split=0.2)

#             model_json = model.to_json()
#             with open("./models_log" + "/" + str(rs) + "_" + "spcup.json", 'w') as json_file:
#                 json_file.write(model_json)
            #             model.save_weights("./models_log" + "/" + str(rs) + "_" + "spcup.h5")
            print("Saved model to disk")


            #             #### json 모델 load
            #             from keras.models import model_from_json
            #             json_file = open("model.json", "r") 
            #             loaded_model_json = json_file.read() 
            #             json_file.close() 
            #             loaded_model = model_from_json(loaded_model_json)

            plt.plot(classifier.history['accuracy'])
            plt.plot(classifier.history['val_accuracy'])
            # plt.plot(classifier.history['loss'])
            # plt.plot(classifier.history['val_loss'])
            plt.legend([ 'accuracy','val_accuracy'], loc = 'upper left')
            plt.show()

            test_loss, test_acc = model.evaluate(X_test,  y_test, verbose=2)

            print('테스트 정확도:', test_acc)

            prediction = model.predict(X_test)




            #######################segment들 합쳐서 파일당 accuracy 계산
            from scipy.stats import mode
            predicted_classes = np.argmax(prediction, axis = 1)
            f = 0
            test_predict=[]
            for i in test.file_split_num:
            #     print(predicted_classes[f:f+i])
                test_predict.append(mode(predicted_classes[f:f+i])[0][0])
                f+=i

            acc_bool = test_predict==y_test_raw
            #             print(test_predict[:100])
            #             print(y_test_raw[:100])
            #             print(acc_bool[:100])
            test_accuracy = acc_bool.tolist().count(True)/len(acc_bool)
            print('************ mel_spectogram')
            print('************ file test_accuracy : ', test_accuracy, '  n_mels : ', n_mels,
                  ', hop_length = ', hop_length,' , n_fft : ',n_fft)
            print('************ X_train.shape : ', X_train.shape)
            print('test_set.size : ', acc_bool.size)
            print('\n\n\n')

            df.append({'n_mels':n_mels,'hop_length':hop_length,'n_fft':n_fft,'rs':rs,'accuracy':test_accuracy,'input_shape':X_train.shape},ignore_index = True)
            df.to_csv("models_log.csv",sep=",")
# Out:
# (64, 32, 1)
# Epoch 1/1000
# 193/193 [==============================] - 35s 163ms/step - loss: 1.5954 - accuracy: 0.5726 - val_loss: 1.2806 - val_accuracy: 0.4377
# Epoch 2/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.3028 - accuracy: 0.8859 - val_loss: 0.9513 - val_accuracy: 0.6771
# Epoch 3/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.2117 - accuracy: 0.9196 - val_loss: 0.2087 - val_accuracy: 0.9262
# Epoch 4/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.2049 - accuracy: 0.9246 - val_loss: 0.1855 - val_accuracy: 0.9267
# Epoch 5/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.1006 - accuracy: 0.9649 - val_loss: 0.1441 - val_accuracy: 0.9501
# Epoch 6/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0902 - accuracy: 0.9656 - val_loss: 0.1086 - val_accuracy: 0.9613
# Epoch 7/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0763 - accuracy: 0.9711 - val_loss: 0.1294 - val_accuracy: 0.9530
# Epoch 8/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0794 - accuracy: 0.9703 - val_loss: 0.1844 - val_accuracy: 0.9401
# Epoch 9/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0503 - accuracy: 0.9810 - val_loss: 0.2034 - val_accuracy: 0.9299
# Epoch 10/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0625 - accuracy: 0.9766 - val_loss: 0.1075 - val_accuracy: 0.9632
# Epoch 11/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0283 - accuracy: 0.9903 - val_loss: 0.1243 - val_accuracy: 0.9542
# Epoch 12/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0251 - accuracy: 0.9914 - val_loss: 0.1321 - val_accuracy: 0.9560
# Epoch 13/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0324 - accuracy: 0.9888 - val_loss: 0.1232 - val_accuracy: 0.9590
# Epoch 14/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0360 - accuracy: 0.9870 - val_loss: 0.1319 - val_accuracy: 0.9605
# Epoch 15/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0203 - accuracy: 0.9926 - val_loss: 0.0915 - val_accuracy: 0.9683
# Epoch 16/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0413 - accuracy: 0.9871 - val_loss: 0.1130 - val_accuracy: 0.9594
# Epoch 17/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0306 - accuracy: 0.9896 - val_loss: 0.1138 - val_accuracy: 0.9629
# Epoch 18/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0290 - accuracy: 0.9896 - val_loss: 0.1161 - val_accuracy: 0.9631
# Epoch 19/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0180 - accuracy: 0.9940 - val_loss: 0.1285 - val_accuracy: 0.9600
# Epoch 20/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0114 - accuracy: 0.9963 - val_loss: 0.0987 - val_accuracy: 0.9686
# Epoch 21/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0076 - accuracy: 0.9979 - val_loss: 0.0944 - val_accuracy: 0.9705
# Epoch 22/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0035 - accuracy: 0.9991 - val_loss: 0.1125 - val_accuracy: 0.9655
# Epoch 23/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0140 - accuracy: 0.9952 - val_loss: 0.2707 - val_accuracy: 0.9291
# Epoch 24/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0303 - accuracy: 0.9891 - val_loss: 0.1221 - val_accuracy: 0.9645
# Epoch 25/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0565 - accuracy: 0.9812 - val_loss: 0.1404 - val_accuracy: 0.9610
# Epoch 26/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0174 - accuracy: 0.9937 - val_loss: 0.1306 - val_accuracy: 0.9668
# Epoch 27/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0253 - accuracy: 0.9910 - val_loss: 0.1209 - val_accuracy: 0.9658
# Epoch 28/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0125 - accuracy: 0.9954 - val_loss: 0.1597 - val_accuracy: 0.9553
# Epoch 29/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0074 - accuracy: 0.9974 - val_loss: 0.1199 - val_accuracy: 0.9710
# Epoch 30/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.1283 - val_accuracy: 0.9683
# Epoch 31/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0041 - accuracy: 0.9986 - val_loss: 0.1299 - val_accuracy: 0.9692
# Epoch 32/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0028 - accuracy: 0.9990 - val_loss: 0.1487 - val_accuracy: 0.9636
# Epoch 33/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0078 - accuracy: 0.9974 - val_loss: 0.2864 - val_accuracy: 0.9398
# Epoch 34/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0613 - accuracy: 0.9805 - val_loss: 0.1632 - val_accuracy: 0.9613
# Epoch 35/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0192 - accuracy: 0.9933 - val_loss: 0.1958 - val_accuracy: 0.9585
# Epoch 36/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0456 - accuracy: 0.9846 - val_loss: 0.1256 - val_accuracy: 0.9660
# Epoch 37/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0145 - accuracy: 0.9947 - val_loss: 0.2333 - val_accuracy: 0.9415
# Epoch 38/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0230 - accuracy: 0.9917 - val_loss: 0.1530 - val_accuracy: 0.9615
# Epoch 39/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0097 - accuracy: 0.9965 - val_loss: 0.1503 - val_accuracy: 0.9628
# Epoch 40/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0136 - accuracy: 0.9955 - val_loss: 0.1500 - val_accuracy: 0.9610
# Epoch 41/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0075 - accuracy: 0.9980 - val_loss: 0.1282 - val_accuracy: 0.9697
# Epoch 42/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0059 - accuracy: 0.9971 - val_loss: 0.1524 - val_accuracy: 0.9666
# Epoch 43/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0043 - accuracy: 0.9985 - val_loss: 0.1347 - val_accuracy: 0.9717
# Epoch 44/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0059 - accuracy: 0.9979 - val_loss: 0.2407 - val_accuracy: 0.9517
# Epoch 45/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0339 - accuracy: 0.9891 - val_loss: 0.1658 - val_accuracy: 0.9623
# Epoch 46/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0321 - accuracy: 0.9891 - val_loss: 0.2555 - val_accuracy: 0.9480
# Epoch 47/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0196 - accuracy: 0.9930 - val_loss: 0.2064 - val_accuracy: 0.9594
# Epoch 48/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0083 - accuracy: 0.9970 - val_loss: 0.1573 - val_accuracy: 0.9691
# Epoch 49/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0036 - accuracy: 0.9989 - val_loss: 0.1804 - val_accuracy: 0.9657
# Epoch 50/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0106 - accuracy: 0.9964 - val_loss: 0.2174 - val_accuracy: 0.9595
# Epoch 51/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0240 - accuracy: 0.9925 - val_loss: 0.2146 - val_accuracy: 0.9529
# Epoch 52/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0155 - accuracy: 0.9944 - val_loss: 0.2000 - val_accuracy: 0.9602
# Epoch 53/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0089 - accuracy: 0.9974 - val_loss: 0.2138 - val_accuracy: 0.9607
# Epoch 54/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0120 - accuracy: 0.9961 - val_loss: 0.2849 - val_accuracy: 0.9537
# Epoch 55/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0154 - accuracy: 0.9953 - val_loss: 0.1687 - val_accuracy: 0.9700
# Epoch 56/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0089 - accuracy: 0.9969 - val_loss: 0.1951 - val_accuracy: 0.9637
# Epoch 57/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0186 - accuracy: 0.9940 - val_loss: 0.2147 - val_accuracy: 0.9592
# Epoch 58/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0180 - accuracy: 0.9946 - val_loss: 0.1971 - val_accuracy: 0.9603
# Epoch 59/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0216 - accuracy: 0.9930 - val_loss: 0.2141 - val_accuracy: 0.9632
# Epoch 60/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0203 - accuracy: 0.9942 - val_loss: 0.1979 - val_accuracy: 0.9658
# Epoch 61/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.1951 - val_accuracy: 0.9658
# Epoch 62/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0062 - accuracy: 0.9977 - val_loss: 0.2512 - val_accuracy: 0.9553
# Epoch 63/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0107 - accuracy: 0.9969 - val_loss: 0.1878 - val_accuracy: 0.9692
# Epoch 64/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0047 - accuracy: 0.9990 - val_loss: 0.2166 - val_accuracy: 0.9649
# Epoch 65/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0052 - accuracy: 0.9983 - val_loss: 0.2579 - val_accuracy: 0.9600
# Epoch 66/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0136 - accuracy: 0.9956 - val_loss: 0.1989 - val_accuracy: 0.9598
# Epoch 67/1000
# 193/193 [==============================] - 28s 146ms/step - loss: 0.0434 - accuracy: 0.9877 - val_loss: 0.2000 - val_accuracy: 0.9642
# Epoch 68/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0072 - accuracy: 0.9976 - val_loss: 0.3189 - val_accuracy: 0.9487
# Epoch 69/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0119 - accuracy: 0.9964 - val_loss: 0.5434 - val_accuracy: 0.9325
# Epoch 70/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0068 - accuracy: 0.9979 - val_loss: 0.1941 - val_accuracy: 0.9681
# Epoch 71/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0078 - accuracy: 0.9981 - val_loss: 0.2985 - val_accuracy: 0.9589
# Epoch 72/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0127 - accuracy: 0.9962 - val_loss: 0.2236 - val_accuracy: 0.9668
# Epoch 73/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0070 - accuracy: 0.9979 - val_loss: 0.2773 - val_accuracy: 0.9534
# Epoch 74/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0191 - accuracy: 0.9948 - val_loss: 0.1924 - val_accuracy: 0.9676
# Epoch 75/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0065 - accuracy: 0.9978 - val_loss: 0.2817 - val_accuracy: 0.9611
# Epoch 76/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0075 - accuracy: 0.9979 - val_loss: 0.3000 - val_accuracy: 0.9608
# Epoch 77/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0091 - accuracy: 0.9974 - val_loss: 0.2233 - val_accuracy: 0.9668
# Epoch 78/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0055 - accuracy: 0.9980 - val_loss: 0.2399 - val_accuracy: 0.9658
# Epoch 79/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0147 - accuracy: 0.9958 - val_loss: 0.4352 - val_accuracy: 0.9474
# Epoch 80/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0420 - accuracy: 0.9899 - val_loss: 0.2388 - val_accuracy: 0.9645
# Epoch 81/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0070 - accuracy: 0.9979 - val_loss: 0.2077 - val_accuracy: 0.9696
# Epoch 82/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0060 - accuracy: 0.9979 - val_loss: 0.2474 - val_accuracy: 0.9662
# Epoch 83/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0062 - accuracy: 0.9981 - val_loss: 0.2968 - val_accuracy: 0.9650
# Epoch 84/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0127 - accuracy: 0.9971 - val_loss: 0.2224 - val_accuracy: 0.9671
# Epoch 85/1000
# 193/193 [==============================] - 28s 144ms/step - loss: 0.0133 - accuracy: 0.9965 - val_loss: 0.2496 - val_accuracy: 0.9653
# Epoch 86/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0212 - accuracy: 0.9950 - val_loss: 0.2788 - val_accuracy: 0.9579
# Epoch 87/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0134 - accuracy: 0.9967 - val_loss: 0.2546 - val_accuracy: 0.9653
# Epoch 88/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 2.8716e-04 - accuracy: 1.0000 - val_loss: 0.2852 - val_accuracy: 0.9653
# Epoch 89/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0021 - accuracy: 0.9991 - val_loss: 0.2864 - val_accuracy: 0.9644
# Epoch 90/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0157 - accuracy: 0.9960 - val_loss: 0.3327 - val_accuracy: 0.9589
# Epoch 91/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0136 - accuracy: 0.9965 - val_loss: 0.2858 - val_accuracy: 0.9618
# Epoch 92/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0087 - accuracy: 0.9980 - val_loss: 0.3125 - val_accuracy: 0.9626
# Epoch 93/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0103 - accuracy: 0.9973 - val_loss: 0.3296 - val_accuracy: 0.9587
# Epoch 94/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0118 - accuracy: 0.9966 - val_loss: 0.2573 - val_accuracy: 0.9650
# Epoch 95/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0029 - accuracy: 0.9986 - val_loss: 0.2719 - val_accuracy: 0.9670
# Epoch 96/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0044 - accuracy: 0.9985 - val_loss: 0.3605 - val_accuracy: 0.9613
# Epoch 97/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0057 - accuracy: 0.9981 - val_loss: 0.3800 - val_accuracy: 0.9532
# Epoch 98/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0225 - accuracy: 0.9952 - val_loss: 0.2310 - val_accuracy: 0.9660
# Epoch 99/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0042 - accuracy: 0.9985 - val_loss: 0.3479 - val_accuracy: 0.9605
# Epoch 100/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0025 - accuracy: 0.9995 - val_loss: 0.2646 - val_accuracy: 0.9689
# Epoch 101/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.2584 - val_accuracy: 0.9692
# Epoch 102/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0056 - accuracy: 0.9981 - val_loss: 0.2735 - val_accuracy: 0.9679
# Epoch 103/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 7.7118e-04 - accuracy: 0.9997 - val_loss: 0.2846 - val_accuracy: 0.9658
# Epoch 104/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0052 - accuracy: 0.9987 - val_loss: 0.7258 - val_accuracy: 0.9386
# Epoch 105/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0378 - accuracy: 0.9922 - val_loss: 0.4800 - val_accuracy: 0.9480
# Epoch 106/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0100 - accuracy: 0.9971 - val_loss: 0.3060 - val_accuracy: 0.9623
# Epoch 107/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0210 - accuracy: 0.9952 - val_loss: 0.2815 - val_accuracy: 0.9686
# Epoch 108/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0054 - accuracy: 0.9984 - val_loss: 0.2908 - val_accuracy: 0.9678
# Epoch 109/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0030 - accuracy: 0.9990 - val_loss: 0.3083 - val_accuracy: 0.9671
# Epoch 110/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0057 - accuracy: 0.9985 - val_loss: 0.3425 - val_accuracy: 0.9623
# Epoch 111/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0163 - accuracy: 0.9966 - val_loss: 0.2675 - val_accuracy: 0.9688
# Epoch 112/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0118 - accuracy: 0.9964 - val_loss: 0.5311 - val_accuracy: 0.9487
# Epoch 113/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0160 - accuracy: 0.9966 - val_loss: 0.2609 - val_accuracy: 0.9684
# Epoch 114/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0099 - accuracy: 0.9973 - val_loss: 0.3012 - val_accuracy: 0.9662
# Epoch 115/1000
# 193/193 [==============================] - 28s 143ms/step - loss: 0.0028 - accuracy: 0.9993 - val_loss: 0.3275 - val_accuracy: 0.9668
# Saved model to disk
# 241/241 - 2s - loss: 0.0955 - accuracy: 0.9670
# 테스트 정확도: 0.9670044183731079
# ************ mel_spectogram
# ************ file test_accuracy :  0.9941666666666666   n_mels :  64 , hop_length =  1024  , n_fft :  2048
# ************ X_train.shape :  (30878, 64, 32, 1)
# test_set.size :  1200
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a8d7ad675935> in <module>
#     108             print('\n\n\n')
#     109
# --> 110             df.append({'n_mels':n_mels,'hop_length':hop_length,'n_fft':n_fft,'rs':rs,'accuracy':test_accuracy,'input_shape':X_train.shape},ignore_index = True)
#     111             df.to_csv("models_log.csv",sep=",")
#     112
#
# NameError: name 'df' is not defined

# %%
test_loss, test_acc = model.evaluate(X_test,  y_test, verbose=2)

        print('테스트 정확도:', test_acc)

        prediction = model.predict(X_test)
# Out:
# 16

# %%
 #######################segment들 합쳐서 파일당 accuracy 계산
from scipy.stats import mode
predicted_classes = np.argmax(prediction, axis = 1)
f = 0
test_predict=[]
for i in test.file_split_num:
#     print(predicted_classes[f:f+i])
    test_predict.append(mode(predicted_classes[f:f+i])[0][0])
#     print(test_predict)
    f+=i

test_predict = np.array(test_predict)
print(len(test.file_split_num))
print(test_predict.shape)
print(y_test_raw.shape)


acc_bool = test_predict==y_test_raw[:-1]
print(acc_bool)
#             print(test_predict[:100])
#             print(y_test_raw[:100])
#             print(acc_bool[:100])
test_accuracy = acc_bool.tolist().count(True)/len(acc_bool)
print('************ mel_spectogram')
print('************ file test_accuracy : ', test_accuracy, '  n_mels : ', n_mels,
      ', hop_length = ', hop_length,' , n_fft : ',n_fft)
print('************ X_train.shape : ', X_train.shape)
print('test_set.size : ', acc_bool.size)
print('\n\n\n')
print('saved_mdel_name : ', "./models_log" + "/" +str(n_mels)+"_"+str(hop_length)+"_"+ str(rs) + "_"
                                         + "othre_feature_label_6_model.h5" )
# df.append({'n_mels':n_mels,'hop_length':hop_length,'n_fft':n_fft,'rs':rs,'accuracy':test_accuracy,'input_shape':X_train.shape},ignore_index = True)
# df.to_csv("models_log.csv",sep=",")

from sklearn.metrics import confusion_matrix
cf = confusion_matrix(y_test_raw[:-1], test_predict)
print('\n\n', cf)
# Out:
# 1199
# (1199,)
# (1200,)
# [ True  True  True ...  True  True  True]
# ************ mel_spectogram
# ************ file test_accuracy :  0.9499582985821518   n_mels :  16 , hop_length =  1024  , n_fft :  2048
# ************ X_train.shape :  (30875, 64, 32, 1)
# test_set.size :  1199
#
#
#
#
# saved_mdel_name :  ./models_log/16_1024_10_othre_feature_label_6_model.h5

# %%
# Out:
# [[200   0   0   0   0   0]
#  [  0 188  11   1   0   0]
#  [  1  17 182   0   0   0]
#  [  0   0   1 199   0   0]
#  [  1   1   0   0 198   0]
#  [  0  10  17   0   0 172]]
